# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Изучение-данных-из-файла" data-toc-modified-id="Изучение-данных-из-файла-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Изучение данных из файла</a></span><ul class="toc-item"><li><span><a href="#Вывод" data-toc-modified-id="Вывод-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Предобработка-данных" data-toc-modified-id="Предобработка-данных-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Предобработка данных</a></span></li><li><span><a href="#Расчёты-и-добавление-результатов-в-таблицу" data-toc-modified-id="Расчёты-и-добавление-результатов-в-таблицу-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Расчёты и добавление результатов в таблицу</a></span></li><li><span><a href="#Исследовательский-анализ-данных" data-toc-modified-id="Исследовательский-анализ-данных-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Исследовательский анализ данных</a></span></li><li><span><a href="#Общий-вывод" data-toc-modified-id="Общий-вывод-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Общий вывод</a></span></li><li><span><a href="#Чек-лист-готовности-проекта" data-toc-modified-id="Чек-лист-готовности-проекта-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Чек-лист готовности проекта</a></span></li></ul></div>

# %% [markdown]
# Привет, меня зовут Головатский Николай, я буду проверять твой проект.
#
# В Практикуме принято общаться на "ты", однако если это неудобно - дай знать, и можем перейти на более официальное общение.
#
# Ниже ты найдешь мои комментарии - **пожалуйста, не перемещай, не изменяй и не удаляй их,** это может усложнить и затянуть повторную проверку.
#
# Я буду использовать цветовую разметку:
#
# <div class="alert alert-block alert-success">
# <b>Комментарий ревьюера✅:</b> Если все сделано хорошо.</div>
#
# <div class="alert alert-block alert-warning">
# <b>Комментарий ревьюера⚠️:</b> Некритичное замечание, реккомендация на будущее. Для принятия проекта исправление не обязательно.</div>
#
# <div class="alert alert-block alert-danger">
# <b>Комментарий ревьюера❌:</b> Критичная ошибка, необходимо исправить, иначе проект не будет принят.
# </div>
#
# Давай работать над проектом в диалоге: если ты что-то меняешь в проекте или отвечаешь на мои комменатри — пиши об этом. Мне будет легче отследить изменения, если ты выделишь свои комментарии:
# Например так:
# <div class="alert alert-block alert-info">
# <b>Комментарий студента:</b>
# Hello World!
# </div>
#
# Если писать особо нечего, просто оставляй комментарий с галочкой
#
# <div class="alert alert-block alert-info">
# <b>Комментарий студента:</b>
# ☑️
# </div>
#
# <div class="alert alert-block alert-success">
# <b>Общее впечатление:</b>
#
# - Спасибо за работу :)
# - Определенно могу сказать, что проект очень сильный;
# - Меня впечатлили твои навыки визуализации, продолжай в том же духе;
# - Мне очень понравилось, как ты детально погружаешься в данные и не упускаешь никаких мелочей;
# - В проекте осталось пара моментов, после правки которых, я смогу принять работу😉
#
# </div>

# %% [markdown]
# # Исследование объявлений о продаже квартир
#
# В вашем распоряжении данные сервиса Яндекc Недвижимость — архив объявлений о продаже квартир в Санкт-Петербурге и соседних населённых пунктах за несколько лет. Нужно научиться определять рыночную стоимость объектов недвижимости. Ваша задача — установить параметры. Это позволит построить автоматизированную систему: она отследит аномалии и мошенническую деятельность.
#
# По каждой квартире на продажу доступны два вида данных. Первые вписаны пользователем, вторые получены автоматически на основе картографических данных. Например, расстояние до центра, аэропорта, ближайшего парка и водоёма.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Комментарий ревьюера✅:</b> Хорошая практика начинать проект с контекста, описания задачи, возможного хода\плана исследования, а также описания имеющихся данных. Очень надеюсь, что ты будешь уделять этому внимание и в последующих проектах</div>

# %% [markdown]
# ## Изучение данных из файла

# %%
import pandas as pd

# %%
data = pd.read_csv(r'C:\Users\corneliu.leahu\OneDrive - Overseas Administration Management\Main Work Folder\Screen docs\STUDIES\CV - Financial Controller Linkedin\Yandex\1. Yandex_Prakctikum\1. Python\3. Исследовательский анализ данных\real_estate_data.csv', sep = '\t')

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>Комментарий ревьюера❌:</b> Таблица прочитана не совсем верно - вижу, что в параметр sep передано значение '\s+' - необходимо передать значение '\t', тогда таблица прочитается правильно. Параметр decimal так же нужно убрать</div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Комментарий студента:</b>
# исправил на sep = '\t', спасибо !
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Комментарий ревьюера✅:</b> 👍</div>

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23699 entries, 0 to 23698
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23699 non-null  int64
#  1   last_price            23699 non-null  float64
#  2   total_area            23699 non-null  float64
#  3   first_day_exposition  23699 non-null  object
#  4   rooms                 23699 non-null  int64
#  5   ceiling_height        14504 non-null  float64
#  6   floors_total          23613 non-null  float64
#  7   living_area           21796 non-null  float64
#  8   floor                 23699 non-null  int64
#  9   is_apartment          2775 non-null   object
#  10  studio                23699 non-null  bool
#  11  open_plan             23699 non-null  bool
#  12  kitchen_area          21421 non-null  float64
#  13  balcony               12180 non-null  float64
#  14  locality_name         23650 non-null  object
# ...

# %%
data
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 0                20  13000000.0      108.00  2019-03-07T00:00:00      3
# 1                 7   3350000.0       40.40  2018-12-04T00:00:00      1
# 2                10   5196000.0       56.00  2015-08-20T00:00:00      2
# 3                 0  64900000.0      159.00  2015-07-24T00:00:00      3
# 4                 2  10000000.0      100.00  2018-06-19T00:00:00      2
# ...             ...         ...         ...                  ...    ...
# 23694             9   9700000.0      133.81  2017-03-21T00:00:00      3
# 23695            14   3100000.0       59.00  2018-01-15T00:00:00      3
# 23696            18   2500000.0       56.70  2018-02-11T00:00:00      2
# 23697            13  11475000.0       76.75  2017-03-28T00:00:00      2
# 23698             4   1350000.0       32.30  2017-07-21T00:00:00      1
#
#        ceiling_height  floors_total  living_area  floor is_apartment  ...  \
# ...

# %%
data.describe()
# Out:
#        total_images    last_price    total_area         rooms  ceiling_height  \
# count  23699.000000  2.369900e+04  23699.000000  23699.000000    14504.000000
# mean       9.858475  6.541549e+06     60.348651      2.070636        2.771499
# std        5.682529  1.088701e+07     35.654083      1.078405        1.261056
# min        0.000000  1.219000e+04     12.000000      0.000000        1.000000
# 25%        6.000000  3.400000e+06     40.000000      1.000000        2.520000
# 50%        9.000000  4.650000e+06     52.000000      2.000000        2.650000
# 75%       14.000000  6.800000e+06     69.900000      3.000000        2.800000
# max       50.000000  7.630000e+08    900.000000     19.000000      100.000000
#
#        floors_total   living_area         floor  kitchen_area       balcony  \
# count  23613.000000  21796.000000  23699.000000  21421.000000  12180.000000
# mean      10.673824     34.457852      5.892358     10.569807      1.150082
# ...

# %%
data.isna().sum()
# Out:
# total_images                0
# last_price                  0
# total_area                  0
# first_day_exposition        0
# rooms                       0
# ceiling_height           9195
# floors_total               86
# living_area              1903
# floor                       0
# is_apartment            20924
# studio                      0
# open_plan                   0
# kitchen_area             2278
# balcony                 11519
# locality_name              49
# airports_nearest         5542
# cityCenters_nearest      5519
# parks_around3000         5518
# parks_nearest           15620
# ponds_around3000         5518
# ponds_nearest           14589
# days_exposition          3181
# dtype: int64

# %%
data.isna().mean()
# Out:
# total_images            0.000000
# last_price              0.000000
# total_area              0.000000
# first_day_exposition    0.000000
# rooms                   0.000000
# ceiling_height          0.387991
# floors_total            0.003629
# living_area             0.080299
# floor                   0.000000
# is_apartment            0.882906
# studio                  0.000000
# open_plan               0.000000
# kitchen_area            0.096122
# balcony                 0.486054
# locality_name           0.002068
# airports_nearest        0.233850
# cityCenters_nearest     0.232879
# parks_around3000        0.232837
# parks_nearest           0.659100
# ponds_around3000        0.232837
# ponds_nearest           0.615596
# days_exposition         0.134225
# dtype: float64

# %%
display(data.head(30))
# Out:
#     total_images  last_price  total_area first_day_exposition  rooms  \
# 0             20  13000000.0      108.00  2019-03-07T00:00:00      3
# 1              7   3350000.0       40.40  2018-12-04T00:00:00      1
# 2             10   5196000.0       56.00  2015-08-20T00:00:00      2
# 3              0  64900000.0      159.00  2015-07-24T00:00:00      3
# 4              2  10000000.0      100.00  2018-06-19T00:00:00      2
# 5             10   2890000.0       30.40  2018-09-10T00:00:00      1
# 6              6   3700000.0       37.30  2017-11-02T00:00:00      1
# 7              5   7915000.0       71.60  2019-04-18T00:00:00      2
# 8             20   2900000.0       33.16  2018-05-23T00:00:00      1
# 9             18   5400000.0       61.00  2017-02-26T00:00:00      3
# 10             5   5050000.0       39.60  2017-11-16T00:00:00      1
# 11             9   3300000.0       44.00  2018-08-27T00:00:00      2
# 12            10   3890000.0       54.00  2016-06-30T00:00:00      2
# ...

# %%
data['is_apartment'].value_counts()
# Out:
# False    2725
# True       50
# Name: is_apartment, dtype: int64

# %%
data[data['floor']== False].head(20)
# Out:
# Empty DataFrame
# Columns: [total_images, last_price, total_area, first_day_exposition, rooms, ceiling_height, floors_total, living_area, floor, is_apartment, studio, open_plan, kitchen_area, balcony, locality_name, airports_nearest, cityCenters_nearest, parks_around3000, parks_nearest, ponds_around3000, ponds_nearest, days_exposition]
# Index: []
#
# [0 rows x 22 columns]

# %% [markdown]
# ### Вывод

# %% [markdown]
# - очень много пропущенных значения, особенно в последних пять столбцов таблички (NaN формат). К приемру столбцы airports_nearest, cityCenters_nearest, parks_around, parks_nearest, ponds_around , ponds_nearest.  -такие столбцы которые заполнены автомотически, это нормально иметь "NaN" если обьект недвижимости не находится рядом с парка.
# - тип данных отсуствует почти во всех столбцах: нет int/float... нынешний формат "non-null object"- получается как строка.
# - пресуствоют столбцы как "balcony","kitchen_area","locality_name" которые содержут смешеные данные: имен и цифрах, вскорее всего это тип данных вписаны пользователем.
# - названия столбцов не соотвействует к данным соделжающих, примеру столбец locality_name содержит цыфры только несколько имен (смешинные данные)...

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>Комментарий ревьюера❌:</b> Смешанные данные в столбцах получались из за неверного параметра sep - сейчас их там нет. Вывод необходимо исправить (касается всего проекта)

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Комментарий ревьюера⚠️:</b> Про чтение файла писал выше - это и есть причина аномалий

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Комментарий ревьюера✅:</b> Хорошее начало, информация о данных изучена👍</div>

# %% [markdown]
# ## Предобработка данных

# %% [markdown]
#  1. Определите и изучите пропущенные значения:
#  - Заполните пропуски, где это уместно. Опишите, почему вы решили заполнить пропуски именно в этих столбцах и как выбрали значения.

# %%
display(data.head(20))
# Out:
#     total_images  last_price  total_area first_day_exposition  rooms  \
# 0             20  13000000.0      108.00  2019-03-07T00:00:00      3
# 1              7   3350000.0       40.40  2018-12-04T00:00:00      1
# 2             10   5196000.0       56.00  2015-08-20T00:00:00      2
# 3              0  64900000.0      159.00  2015-07-24T00:00:00      3
# 4              2  10000000.0      100.00  2018-06-19T00:00:00      2
# 5             10   2890000.0       30.40  2018-09-10T00:00:00      1
# 6              6   3700000.0       37.30  2017-11-02T00:00:00      1
# 7              5   7915000.0       71.60  2019-04-18T00:00:00      2
# 8             20   2900000.0       33.16  2018-05-23T00:00:00      1
# 9             18   5400000.0       61.00  2017-02-26T00:00:00      3
# 10             5   5050000.0       39.60  2017-11-16T00:00:00      1
# 11             9   3300000.0       44.00  2018-08-27T00:00:00      2
# 12            10   3890000.0       54.00  2016-06-30T00:00:00      2
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23699 entries, 0 to 23698
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23699 non-null  int64
#  1   last_price            23699 non-null  float64
#  2   total_area            23699 non-null  float64
#  3   first_day_exposition  23699 non-null  object
#  4   rooms                 23699 non-null  int64
#  5   ceiling_height        14504 non-null  float64
#  6   floors_total          23613 non-null  float64
#  7   living_area           21796 non-null  float64
#  8   floor                 23699 non-null  int64
#  9   is_apartment          2775 non-null   object
#  10  studio                23699 non-null  bool
#  11  open_plan             23699 non-null  bool
#  12  kitchen_area          21421 non-null  float64
#  13  balcony               12180 non-null  float64
#  14  locality_name         23650 non-null  object
# ...

# %%
# там где пропуск ставлю 0, скорее всего нет балконов
data['balcony']= data['balcony'].fillna(value = 0)

# %%
# там где пропуск ставлю 0, скорее всего нет этажей, это может быть дом
data['floor']= data['floor'].fillna(value = 0)

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Комментарий ревьюера✅:</b> Согласен😉</div>

# %%
# этот столбец почти не содержит данных (days_exposition 0.988354)
data['days_exposition']= data['days_exposition'].fillna(value = 0)

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Комментарий ревьюера✅:</b> Еще он не участвует в исследовании)</div>

# %%
data.fillna({
    'airports_nearest': 0,
    'cityCenters_nearest': 0, 
    'parks_around3000':0,
    'parks_nearest':0,
    'ponds_around3000':0,
    'ponds_nearest':0,
    'kitchen_area':0,
    'living_area':0,
},inplace =True)

# %%
data.isna().sum()
# Out:
# total_images                0
# last_price                  0
# total_area                  0
# first_day_exposition        0
# rooms                       0
# ceiling_height           9195
# floors_total               86
# living_area                 0
# floor                       0
# is_apartment            20924
# studio                      0
# open_plan                   0
# kitchen_area                0
# balcony                     0
# locality_name              49
# airports_nearest            0
# cityCenters_nearest         0
# parks_around3000            0
# parks_nearest               0
# ponds_around3000            0
# ponds_nearest               0
# days_exposition             0
# dtype: int64

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Комментарий ревьюера⚠️:</b> Вместо inplace советую переприсваивать значение переменной:
#
# Пример: df = df.метод
#
#
#
# [Подробнее об этом тут](https://towardsdatascience.com/why-you-should-probably-never-use-pandas-inplace-true-9f9f211849e4)</div>

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Комментарий ревьюера⚠️:</b> Есть еще один интересный способ заполнения kitchen_area и living_area. Мы можем найти медианный коофициент этой площади от total_area, и заполнить пропуски значениями total_area, умноженными на коофициент. В идеале - это можно сделать в разрезе количества комнат😉

# %% [markdown]
# заполняю столбцы выше нулями потому-что 0 обозначит что нету данных скажем по аеропортам или  обьект недвижимости не находится в близи от cityCenters_nearest. как  бы мы не интерпретируем данные в этих столбцах : каличество или расстояние, 0 обозночает нет данных

# %%
# в этот столбец есть уже 0, и я заменю на 0 все 2780 данные, это будут значит со нет данные так как дистанция не может быть 0 (locality_name)           2780
data['locality_name'] = data['locality_name'].fillna('unknown')

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>Комментарий ревьюера❌:</b> После исправлений выше, этот столбец станет строкового типа. Так как пропусков в нем очень мало, их можно или удалить, или заполнить заглушкой ('unknown')</div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Комментарий студента:</b>
# поменял fillna с 0 на Unknown и да, увидел что тип Данных стал теперь "object" спасибо !
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Комментарий ревьюера✅:</b> 😉

# %%
data['ceiling_height'] = data['ceiling_height'].fillna(data['ceiling_height'].median())

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>Комментарий ревьюера❌:</b> Стобец имеет численный формат, заполнять его строкой не стоит. Лучше заполнить медианой

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Комментарий студента:</b>
# сделано !
# </div>

# %%
data['is_apartment'] = data['is_apartment'].fillna('False')

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>Комментарий ревьюера❌:</b> Стобец имеет логический формат, заполнять его строкой не стоит. Было бы логично заполнить значениями False

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Комментарий студента:</b>
# сделано !
# </div>

# %%
data['floors_total'] = data['floors_total'].fillna(0)

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>Комментарий ревьюера❌:</b> Стобец имеет численный формат, заполнять его строкой не стоит. Так как пропусков очень мало, их можно или чем нибудь заполнить, или удалить

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Комментарий студента:</b>
# сделано ! заполнил нулями
# </div>

# %%
data.isna().sum()
# Out:
# total_images            0
# last_price              0
# total_area              0
# first_day_exposition    0
# rooms                   0
# ceiling_height          0
# floors_total            0
# living_area             0
# floor                   0
# is_apartment            0
# studio                  0
# open_plan               0
# kitchen_area            0
# balcony                 0
# locality_name           0
# airports_nearest        0
# cityCenters_nearest     0
# parks_around3000        0
# parks_nearest           0
# ponds_around3000        0
# ponds_nearest           0
# days_exposition         0
# dtype: int64

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>Комментарий ревьюера❌:</b> Сейчас сложно проверять проект дальше, исправь пожалуйста чтение файла, тогда ты получишь корректные данные😉

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Комментарий студента:</b>
# данные были исправлены ! метод isna() дает 0
# </div>

# %%
display(data)
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 0                20  13000000.0      108.00  2019-03-07T00:00:00      3
# 1                 7   3350000.0       40.40  2018-12-04T00:00:00      1
# 2                10   5196000.0       56.00  2015-08-20T00:00:00      2
# 3                 0  64900000.0      159.00  2015-07-24T00:00:00      3
# 4                 2  10000000.0      100.00  2018-06-19T00:00:00      2
# ...             ...         ...         ...                  ...    ...
# 23694             9   9700000.0      133.81  2017-03-21T00:00:00      3
# 23695            14   3100000.0       59.00  2018-01-15T00:00:00      3
# 23696            18   2500000.0       56.70  2018-02-11T00:00:00      2
# 23697            13  11475000.0       76.75  2017-03-28T00:00:00      2
# 23698             4   1350000.0       32.30  2017-07-21T00:00:00      1
#
#        ceiling_height  floors_total  living_area  floor is_apartment  ...  \
# ...

# %% [markdown]
# не заменяю данные в столбцы "studio","open_plan","kitchen_area" потому что здечь смешенные данные, может быть и 0 и False и названия города... с этими колокоми я не думаю работать дальше в проекте... чтобы найти медиану/строить график тгд ...

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>Комментарий ревьюера❌:</b> Вывод необходимо актуализировать

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Комментарий студента:</b>
# сделано ! сейчас данные выглядят лучше... цифры к фыфрам , текст к текстам
# </div>

# %% [markdown]
# ниже, проеверяю данные п последние 3 столбцах, и нахожу очень разные и смешенные данные которые пока не могу заменять

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Комментарий студента:</b>
# коментарии выше не актуален, данные выглядят более понятлевы
# </div>

# %%
data['balcony'].value_counts()
# Out:
# 0.0    15277
# 1.0     4195
# 2.0     3659
# 5.0      304
# 4.0      183
# 3.0       81
# Name: balcony, dtype: int64

# %%
data['open_plan'].value_counts()
# Out:
# False    23632
# True        67
# Name: open_plan, dtype: int64

# %%
data['living_area'].value_counts().sort_values(ascending = False)
# Out:
# 0.00      1903
# 18.00      882
# 17.00      675
# 30.00      598
# 16.00      486
#           ...
# 63.72        1
# 159.60       1
# 33.06        1
# 47.43        1
# 42.55        1
# Name: living_area, Length: 1783, dtype: int64

# %%
data[data['living_area']==0]
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 3                 0  64900000.0      159.00  2015-07-24T00:00:00      3
# 7                 5   7915000.0       71.60  2019-04-18T00:00:00      2
# 30               12   2200000.0       32.80  2018-02-19T00:00:00      1
# 37               10   1990000.0       45.80  2017-10-28T00:00:00      2
# 44               13   5350000.0       40.00  2018-11-18T00:00:00      1
# ...             ...         ...         ...                  ...    ...
# 23642            14   5950000.0       80.30  2018-07-03T00:00:00      3
# 23663            12   6400000.0       88.00  2018-01-12T00:00:00      4
# 23670             9   2450000.0       45.60  2018-02-08T00:00:00      1
# 23679             0   2500000.0       35.00  2017-12-08T00:00:00      1
# 23697            13  11475000.0       76.75  2017-03-28T00:00:00      2
#
#        ceiling_height  floors_total  living_area  floor is_apartment  ...  \
# ...

# %%
data[data['is_apartment']==0]
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 11                9   3300000.0        44.0  2018-08-27T00:00:00      2
# 25                3   6800000.0        76.0  2015-10-01T00:00:00      2
# 29                9   8600000.0       100.0  2016-04-09T00:00:00      3
# 36               13   3790000.0        45.0  2017-01-25T00:00:00      2
# 41               16   7900000.0        74.0  2016-05-04T00:00:00      3
# ...             ...         ...         ...                  ...    ...
# 23665            11   4250000.0        47.0  2016-05-20T00:00:00      1
# 23667            14   9990000.0        90.0  2017-01-23T00:00:00      3
# 23671             3   3450000.0        35.3  2017-04-14T00:00:00      1
# 23678            10   3500000.0        43.0  2016-05-19T00:00:00      2
# 23682            11   2350000.0        35.6  2016-06-23T00:00:00      1
#
#        ceiling_height  floors_total  living_area  floor is_apartment  ...  \
# ...

# %%
data['floor'].value_counts()
# Out:
# 2     3368
# 3     3073
# 1     2917
# 4     2804
# 5     2621
# 6     1305
# 7     1218
# 8     1083
# 9     1051
# 10     687
# 12     526
# 11     523
# 13     379
# 15     343
# 14     337
# 16     315
# 17     227
# 18     178
# 19     147
# 21     125
# 22     113
# 20     110
# 23     100
# 24      63
# 25      46
# 26      24
# 27      10
# 28       1
# 30       1
# 29       1
# 32       1
# 33       1
# 31       1
# Name: floor, dtype: int64

# %% [markdown]
# 2. Приведите данные к нужным типам:
#  - Поясните, в каких столбцах нужно изменить тип данных и почему.

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23699 entries, 0 to 23698
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23699 non-null  int64
#  1   last_price            23699 non-null  float64
#  2   total_area            23699 non-null  float64
#  3   first_day_exposition  23699 non-null  object
#  4   rooms                 23699 non-null  int64
#  5   ceiling_height        23699 non-null  float64
#  6   floors_total          23699 non-null  float64
#  7   living_area           23699 non-null  float64
#  8   floor                 23699 non-null  int64
#  9   is_apartment          23699 non-null  object
#  10  studio                23699 non-null  bool
#  11  open_plan             23699 non-null  bool
#  12  kitchen_area          23699 non-null  float64
#  13  balcony               23699 non-null  float64
#  14  locality_name         23699 non-null  object
# ...

# %%
display(data.head())
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20  13000000.0       108.0  2019-03-07T00:00:00      3
# 1             7   3350000.0        40.4  2018-12-04T00:00:00      1
# 2            10   5196000.0        56.0  2015-08-20T00:00:00      2
# 3             0  64900000.0       159.0  2015-07-24T00:00:00      3
# 4             2  10000000.0       100.0  2018-06-19T00:00:00      2
#
#    ceiling_height  floors_total  living_area  floor is_apartment  ...  \
# 0            2.70          16.0         51.0      8        False  ...
# 1            2.65          11.0         18.6      1        False  ...
# 2            2.65           5.0         34.3      4        False  ...
# 3            2.65          14.0          0.0      9        False  ...
# 4            3.03          14.0         32.0     13        False  ...
#
#    kitchen_area  balcony    locality_name  airports_nearest  \
# 0          25.0      0.0  Санкт-Петербург           18863.0
# ...

# %%
columns_to_numeric = ['total_images','last_price','total_area','rooms','ceiling_height','floors_total','airports_nearest','cityCenters_nearest','parks_around3000','parks_nearest','ponds_around3000','ponds_nearest','days_exposition','kitchen_area','living_area']

# %%
data[columns_to_numeric] = data[columns_to_numeric].apply(pd.to_numeric,errors = 'coerce')

# %%
for col in columns_to_numeric:
    data[col]= data[col].astype('int',errors='ignore')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23699 entries, 0 to 23698
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23699 non-null  int32
#  1   last_price            23699 non-null  int32
#  2   total_area            23699 non-null  int32
#  3   first_day_exposition  23699 non-null  object
#  4   rooms                 23699 non-null  int32
#  5   ceiling_height        23699 non-null  int32
#  6   floors_total          23699 non-null  int32
#  7   living_area           23699 non-null  int32
#  8   floor                 23699 non-null  int64
#  9   is_apartment          23699 non-null  object
#  10  studio                23699 non-null  bool
#  11  open_plan             23699 non-null  bool
#  12  kitchen_area          23699 non-null  int32
#  13  balcony               23699 non-null  float64
#  14  locality_name         23699 non-null  object
# ...

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>Комментарий ревьюера❌:</b> Тут мы видим, что в ceiling_height пропуски остались
#
# Если я правильно понял, после исправления параметра sep, ты не пересматривал работу. Так как данные изменились (а изменились они достаточно сильно) - необходимо пересмотреть все проделанные шаги и выводы. Пока что остановлюсь на этом месте, буду ждать новую версию проекта😉

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Комментарий студента:</b>
# Вы не ошибайтесь... пересматривал данные вроде сейчас не должны быть никакие пропуск... все читсо !
# </div>

# %%
data.isna().sum()
# Out:
# total_images            0
# last_price              0
# total_area              0
# first_day_exposition    0
# rooms                   0
# ceiling_height          0
# floors_total            0
# living_area             0
# floor                   0
# is_apartment            0
# studio                  0
# open_plan               0
# kitchen_area            0
# balcony                 0
# locality_name           0
# airports_nearest        0
# cityCenters_nearest     0
# parks_around3000        0
# parks_nearest           0
# ponds_around3000        0
# ponds_nearest           0
# days_exposition         0
# dtype: int64

# %%
data[data['ceiling_height']=='']
# Out:
# Empty DataFrame
# Columns: [total_images, last_price, total_area, first_day_exposition, rooms, ceiling_height, floors_total, living_area, floor, is_apartment, studio, open_plan, kitchen_area, balcony, locality_name, airports_nearest, cityCenters_nearest, parks_around3000, parks_nearest, ponds_around3000, ponds_nearest, days_exposition]
# Index: []
#
# [0 rows x 22 columns]

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Комментарий ревьюера✅:</b> Двигаемся дальше😉</div>

# %% [markdown]
# ## Расчёты и добавление результатов в таблицу

# %%
#цену квадратного метра;
data['price_per_m2'] =  data['last_price']/ data['total_area']

# %%
#день недели, месяц и год публикации объявления;
data['first_day_exposition'] = pd.to_datetime(data['first_day_exposition'], format = '%Y-%m-%dT%H:%M:%S',errors='coerce' )

# %%
data['target_date'] = pd.to_datetime(data['first_day_exposition'], format = '%Y-%m-%dT%H:%M:%S',errors='coerce' )

# %%
data['Year']=data['target_date'].dt.year

# %%
data['month']=data['target_date'].dt.month

# %%
data['day']=data['target_date'].dt.day

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23699 entries, 0 to 23698
# Data columns (total 27 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23699 non-null  int32
#  1   last_price            23699 non-null  int32
#  2   total_area            23699 non-null  int32
#  3   first_day_exposition  23699 non-null  datetime64[ns]
#  4   rooms                 23699 non-null  int32
#  5   ceiling_height        23699 non-null  int32
#  6   floors_total          23699 non-null  int32
#  7   living_area           23699 non-null  int32
#  8   floor                 23699 non-null  int64
#  9   is_apartment          23699 non-null  object
#  10  studio                23699 non-null  bool
#  11  open_plan             23699 non-null  bool
#  12  kitchen_area          23699 non-null  int32
#  13  balcony               23699 non-null  float64
#  14  locality_name         23699 non-null  object
# ...

# %% [markdown]
# - этаж квартиры; варианты — первый, последний, другой; (последний - этаж 60)

# %%
data['floors_total'].sort_values(ascending = False)
# Out:
# 2253     60
# 16731    52
# 16934    37
# 11079    36
# 5807     36
#          ..
# 10058     0
# 7922      0
# 11129     0
# 11389     0
# 8478      0
# Name: floors_total, Length: 23699, dtype: int32

# %%
data['floors_total'].describe()
# Out:
# count    23699.000000
# mean        10.635090
# std          6.616396
# min          0.000000
# 25%          5.000000
# 50%          9.000000
# 75%         16.000000
# max         60.000000
# Name: floors_total, dtype: float64

# %%
#этаж квартиры; варианты — первый, последний, другой;
floor_category = []


for floor in data['floors_total']:
    if floor == 1:
        category = "первый"
    elif floor == 60:
        category = "последний"
    else:
        category='другой'
    floor_category.append(category)

# %%
data['floor_variants'] = floor_category

# %%
data
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 0                20    13000000         108           2019-03-07      3
# 1                 7     3350000          40           2018-12-04      1
# 2                10     5196000          56           2015-08-20      2
# 3                 0    64900000         159           2015-07-24      3
# 4                 2    10000000         100           2018-06-19      2
# ...             ...         ...         ...                  ...    ...
# 23694             9     9700000         133           2017-03-21      3
# 23695            14     3100000          59           2018-01-15      3
# 23696            18     2500000          56           2018-02-11      2
# 23697            13    11475000          76           2017-03-28      2
# 23698             4     1350000          32           2017-07-21      1
#
#        ceiling_height  floors_total  living_area  floor is_apartment  ...  \
# ...

# %% [markdown]
# - соотношение жилой и общей площади, а также отношение площади кухни к общей.

# %%
data['living_area'].value_counts()
# Out:
# 0      1903
# 17     1578
# 18     1500
# 30     1027
# 16     1007
#        ...
# 129       1
# 216       1
# 322       1
# 157       1
# 181       1
# Name: living_area, Length: 208, dtype: int64

# %%
data['total_area'].value_counts()
# Out:
# 45     763
# 44     697
# 42     657
# 31     645
# 35     569
#       ...
# 268      1
# 398      1
# 223      1
# 507      1
# 297      1
# Name: total_area, Length: 310, dtype: int64

# %%
data['total_area'].isna().mean()
# Out:
# 0.0

# %%
data['kitchen_area'].isna().sum()
# Out:
# 0

# %%
#соотношение жилой и общей площади
data['%_living_area'] = data['living_area']/ data['total_area']

# %%
#соотношение re[yb] и общей площади
data['%_kitchen_area'] = data['kitchen_area']/ data['total_area']

# %%
data['%_kitchen_area'].value_counts()
# Out:
# 0.000000    2278
# 0.200000     508
# 0.250000     442
# 0.166667     432
# 0.142857     356
#             ...
# 0.074380       1
# 0.347368       1
# 0.111607       1
# 0.471545       1
# 0.097744       1
# Name: %_kitchen_area, Length: 1638, dtype: int64

# %%
data['floor_variants'].value_counts()
# Out:
# другой       23673
# первый          25
# последний        1
# Name: floor_variants, dtype: int64

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Комментарий ревьюера✅</b> Все рассчеты проведены верно, молодец🔥
# </div>

# %% [markdown]
# ## Исследовательский анализ данных

# %% [markdown]
#     - Изучите следующие параметры: площадь, цена, число комнат, высота потолков. Постройте гистограммы для каждого параметра.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data.describe()
# Out:
#        total_images    last_price    total_area         rooms  ceiling_height  \
# count  23699.000000  2.369900e+04  23699.000000  23699.000000    23699.000000
# mean       9.858475  6.541549e+06     60.120511      2.070636        2.142411
# std        5.682529  1.088701e+07     35.665822      1.078405        1.033337
# min        0.000000  1.219000e+04     12.000000      0.000000        1.000000
# 25%        6.000000  3.400000e+06     40.000000      1.000000        2.000000
# 50%        9.000000  4.650000e+06     52.000000      2.000000        2.000000
# 75%       14.000000  6.800000e+06     69.000000      3.000000        2.000000
# max       50.000000  7.630000e+08    900.000000     19.000000      100.000000
#
#        floors_total   living_area         floor  kitchen_area       balcony  \
# count  23699.000000  23699.000000  23699.000000  23699.000000  23699.000000
# mean      10.635090     31.464534      5.892358      9.329254      0.591080
# ...

# %%
#Изучите следующие параметры: площадь
data['total_area'].plot(kind = 'hist',
                        range = (0,350),
                        label='raw',
                        figsize=(16, 6))
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
data['total_area'].plot(kind = 'hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
data['total_area'].describe()
# Out:
# count    23699.000000
# mean        60.120511
# std         35.665822
# min         12.000000
# 25%         40.000000
# 50%         52.000000
# 75%         69.000000
# max        900.000000
# Name: total_area, dtype: float64

# %% [markdown]
# беря в расчет всю базу данных, самые частые предложения квартир с площадю 25- 75 метров. Миниму 12 метпров, макс 900 метров. срелняя площадь 60м, стандартное отклонения 35 м. Достаточно мало предложения по квартир с площадю >200 м

# %%
#Изучите следующие параметры: цена
data.boxplot(column = 'price_per_m2')
# Out:
# <AxesSubplot:>

# %%
data['price_per_m2'].plot()
# Out:
# <AxesSubplot:>

# %%
ax = data['price_per_m2'].hist(bins = 15, range = (100, 750000),figsize=(16, 6))
ax.set_title('price_per_m2 analyse')
ax.set_xlabel('m2')
ax.set_ylabel('count')
# Out:
# Text(0, 0.5, 'count')

# %%
data['price_per_m2'].hist(bins = 10, range = (5000, 200000),figsize=(16, 6))
# Out:
# <AxesSubplot:>

# %% [markdown]
# отличная гистаграма получается, легко понять что самая расспрастраненая цена на рынке в интервале 70 - 110000 руб, при этом средняя цена 99874 руб. есть предложения и по 175К + но это редкие обявления , скорее всего это квартипы класса люкс

# %%
data['price_per_m2'].describe()
# Out:
# count    2.369900e+04
# mean     9.987413e+04
# std      5.041842e+04
# min      1.118349e+02
# 25%      7.698551e+04
# 50%      9.545455e+04
# 75%      1.148649e+05
# max      1.907500e+06
# Name: price_per_m2, dtype: float64

# %%
data['price_per_m2'].describe()
# Out:
# count    2.369900e+04
# mean     9.987413e+04
# std      5.041842e+04
# min      1.118349e+02
# 25%      7.698551e+04
# 50%      9.545455e+04
# 75%      1.148649e+05
# max      1.907500e+06
# Name: price_per_m2, dtype: float64

# %%
data['price_per_m2'].max()
# Out:
# 1907500.0

# %%
data['price_per_m2'].min()
# Out:
# 111.8348623853211

# %%
data['price_per_m2'].mean()
# Out:
# 99874.13359933077

# %%
data['price_per_m2'].median()
# Out:
# 95454.54545454546

# %%
#vИзучите следующие параметры: комнаты
data['rooms'].hist(range=(0,19), bins= 20, legend = True,figsize=(16, 6) )
# Out:
# <AxesSubplot:>

# %%
data['rooms'].describe()
# Out:
# count    23699.000000
# mean         2.070636
# std          1.078405
# min          0.000000
# 25%          1.000000
# 50%          2.000000
# 75%          3.000000
# max         19.000000
# Name: rooms, dtype: float64

# %% [markdown]
# у самой большой квартире 19 комнат,но уже квартиры начиная с 7 комнат уже редкость... то же самое могу сказать и по студии

# %%
data['rooms'].hist(range=(0,10), bins= 10, legend = True, figsize=(16, 6))
# Out:
# <AxesSubplot:>

# %% [markdown]
# все таки квартиры имеют чаще всего 1-3 комнат, это 75% всех данных

# %%
data.boxplot(column = 'rooms')
# Out:
# <AxesSubplot:>

# %% [markdown]
# а вот квартиры с 4-6 комнат всртечаются по реже... они не входят в 75% ; больше чем 7 комнат - ниже 25% данных

# %%
# Изучите следующие параметры: высота
data['ceiling_height'].hist(range=(1,5), bins= 10,legend = True,figsize=(16, 6))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# C:\Users\CORNEL~1.LEA\AppData\Local\Temp/ipykernel_13180/2676993118.py in <module>
#       1 # Изучите следующие параметры: высота
# ----> 2 data['ceiling_height'].hist(range=(1,5), bins= 10,legend = True,figsize=(16, 6))
#
# NameError: name 'data' is not defined

# %% [markdown]
# высота потолков 2 метра в основном, есть и по 3 метра, но гораздо меньше

# %%
data['ceiling_height'].describe()
# Out:
# count    23699.000000
# mean         2.142411
# std          1.033337
# min          1.000000
# 25%          2.000000
# 50%          2.000000
# 75%          2.000000
# max        100.000000
# Name: ceiling_height, dtype: float64

# %%
data['ceiling_height'].value_counts()
# Out:
# 2      21055
# 3       2527
# 4         77
# 27         9
# 25         7
# 5          7
# 8          4
# 1          3
# 32         2
# 6          1
# 10         1
# 22         1
# 24         1
# 20         1
# 14         1
# 26         1
# 100        1
# Name: ceiling_height, dtype: int64

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>Комментарий ревьюера❌:</b> Сюда необходимо добавить краткий вывод по изучению распределений. В остальном все верно, распределения изучены правильно
#
# советую попробовать в использовании параметр figsize (например figsize=(16, 6)), так будет удобнее изучать графики)</div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Комментарий студента:</b>
# ☑️ я добавил выше краткие выводы у каждого графика площадь,цена, количество комна, высота потолка + figsize=(16, 6), спасибо!
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Комментарий ревьюера_v2✅:</b> Другое дело🔥 </div>

# %% [markdown]
#      - Изучите время продажи квартиры. Постройте гистограмму. Посчитайте среднее и медиану. Опишите, сколько обычно занимает продажа. Когда можно считать, что продажи прошли очень быстро, а когда необычно долго?

# %%
data['days_exposition'].describe()
# Out:
# count    23699.000000
# mean       156.608844
# std        213.546873
# min          0.000000
# 25%         22.000000
# 50%         74.000000
# 75%        199.000000
# max       1580.000000
# Name: days_exposition, dtype: float64

# %%
data['days_exposition'].value_counts().sort_values(ascending = False)
# Out:
# 0       3181
# 45       880
# 60       538
# 7        234
# 30       208
#         ...
# 1146       1
# 1278       1
# 1206       1
# 1125       1
# 971        1
# Name: days_exposition, Length: 1142, dtype: int64

# %% [markdown]
# очень много данных включают нулей , невозможно чтлбы 0 дней было размещено объявление , прийдется сделать фильтр позже и исключить данные с 0 , пока попробую и с этим построить графики анализов

# %%
data['days_exposition'].hist()
# Out:
# <AxesSubplot:>

# %%
data['days_exposition'].describe()
# Out:
# count    23699.000000
# mean       156.608844
# std        213.546873
# min          0.000000
# 25%         22.000000
# 50%         74.000000
# 75%        199.000000
# max       1580.000000
# Name: days_exposition, dtype: float64

# %%
data['days_exposition'].value_counts(ascending =False).head(10)
# Out:
# 0     3181
# 45     880
# 60     538
# 7      234
# 30     208
# 90     204
# 4      176
# 3      158
# 5      152
# 14     148
# Name: days_exposition, dtype: int64

# %% [markdown]
# - Уберите редкие и выбивающиеся значения. Опишите, какие особенности обнаружили.

# %%
good_data = data.query('1 < days_exposition <= 800')

# %%
good_data['days_exposition'].describe()
# Out:
# count    19926.000000
# mean       155.953227
# std        165.080833
# min          2.000000
# 25%         44.000000
# 50%         91.000000
# 75%        212.000000
# max        800.000000
# Name: days_exposition, dtype: float64

# %%
good_data['days_exposition'].hist()
# Out:
# <AxesSubplot:>

# %% [markdown]
#  - Уберите редкие и выбивающиеся значения. Опишите, какие особенности обнаружили.

# %% [markdown]
# Вывод:
# я решил убрать все значения выше 800 дней, тагже нулевые значения тоесть те продажи которые прошли очень быстро (0 дней),и когда необычно долго(>800).При фиоьтпации данных, заметил что значения mean и median понменялись (минимум стало 2 дня и среднее 155 дней), у нас получились более структурированные данные на значемый интервал, на который можно построить гистаграму и провести точный аналих данных.

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Комментарий ревьюера⚠️</b> Очень хорошо, что ты прокомментировал свое решение. Единственное, что бы я добавил, это проверку количества дынных, перед удалением. Вдруг мы удалим половину таблицы?

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Комментарий студента:</b>
# ☑️ Я понял, да, часть данных не взято в расчет, это 15%
# </div>

# %% [markdown]
# days_exposition

# %%
len(data)
# Out:
# 23699

# %%
len(good_data)
# Out:
# 19926

# %%
(len(data) - len(good_data))/len(data)
# Out:
# 0.15920502974809064

# %% [markdown]
# - Какие факторы больше всего влияют на стоимость квартиры? Изучите, зависит ли цена от площади, числа комнат, удалённости от центра. Изучите зависимость цены от того, на каком этаже расположена квартира: первом, последнем или другом. Также изучите зависимость от даты размещения: дня недели, месяца и года.

# %%
display(data)
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 0                20    13000000         108           2019-03-07      3
# 1                 7     3350000          40           2018-12-04      1
# 2                10     5196000          56           2015-08-20      2
# 3                 0    64900000         159           2015-07-24      3
# 4                 2    10000000         100           2018-06-19      2
# ...             ...         ...         ...                  ...    ...
# 23694             9     9700000         133           2017-03-21      3
# 23695            14     3100000          59           2018-01-15      3
# 23696            18     2500000          56           2018-02-11      2
# 23697            13    11475000          76           2017-03-28      2
# 23698             4     1350000          32           2017-07-21      1
#
#        ceiling_height  floors_total  living_area  floor is_apartment  ...  \
# ...

# %%
#Изучите, зависит ли цена от площади, числа комнат, удалённости от центра.
data[['floor_variants','rooms','cityCenters_nearest','total_area','ceiling_height','Year','month']].corrwith(data['price_per_m2'])
# Out:
# rooms                  0.052191
# cityCenters_nearest    0.034686
# total_area             0.298678
# ceiling_height         0.115037
# Year                   0.009775
# month                 -0.001996
# dtype: float64

# %% [markdown]
# уже видим что площадь и высота потолков квартирв влеяет на цену кводратного метра, прямая и достаточно сильная корелация. меньше на цену влеяют другие параметрвы пока... изучем данные через таблиц

# %%
data_corr = pd.DataFrame(data=data, columns = ['rooms','cityCenters_nearest','total_area','price_per_m2'])

# %%
data_corr.corr()
# Out:
#                         rooms  cityCenters_nearest  total_area  price_per_m2
# rooms                1.000000            -0.059845    0.758347      0.052191
# cityCenters_nearest -0.059845             1.000000   -0.077069      0.034686
# total_area           0.758347            -0.077069    1.000000      0.298678
# price_per_m2         0.052191             0.034686    0.298678      1.000000

# %%
pd.plotting.scatter_matrix(data_corr,figsize=(9, 9))
# Out:
# array([[<AxesSubplot:xlabel='rooms', ylabel='rooms'>,
#         <AxesSubplot:xlabel='cityCenters_nearest', ylabel='rooms'>,
#         <AxesSubplot:xlabel='total_area', ylabel='rooms'>,
#         <AxesSubplot:xlabel='price_per_m2', ylabel='rooms'>],
#        [<AxesSubplot:xlabel='rooms', ylabel='cityCenters_nearest'>,
#         <AxesSubplot:xlabel='cityCenters_nearest', ylabel='cityCenters_nearest'>,
#         <AxesSubplot:xlabel='total_area', ylabel='cityCenters_nearest'>,
#         <AxesSubplot:xlabel='price_per_m2', ylabel='cityCenters_nearest'>],
#        [<AxesSubplot:xlabel='rooms', ylabel='total_area'>,
#         <AxesSubplot:xlabel='cityCenters_nearest', ylabel='total_area'>,
#         <AxesSubplot:xlabel='total_area', ylabel='total_area'>,
#         <AxesSubplot:xlabel='price_per_m2', ylabel='total_area'>],
#        [<AxesSubplot:xlabel='rooms', ylabel='price_per_m2'>,
#         <AxesSubplot:xlabel='cityCenters_nearest', ylabel='price_per_m2'>,
# ...

# %%
data.sort_values('price_per_m2').plot(x='total_area', y='price_per_m2', kind='scatter')
# Out:
# <AxesSubplot:xlabel='total_area', ylabel='price_per_m2'>

# %% [markdown]
# большинство квартир площадю меньше чем 200 ми ценаоброзование жилого недвижимости не сильно варирует в большинтсва случии.

# %%
pivot_table_total_area = data.pivot_table(index = 'total_area', values = 'price_per_m2', aggfunc = ['mean','count','median'] )

# %%
pivot_table_total_area.columns= ['mean','count','median']

# %%
pivot_table_total_area.plot(y = 'median',style = 'o')
# Out:
# <AxesSubplot:xlabel='total_area'>

# %%
data.plot(y = 'price_per_m2', x = 'total_area')
# Out:
# <AxesSubplot:xlabel='total_area'>

# %%
data['price_per_m2'].corr(data['total_area'])
# Out:
# 0.2986781984042801

# %% [markdown]
# зовисимости цены от площади

# %%
data.corr(method ='pearson')
# Out:
#                      total_images  last_price  total_area     rooms  \
# total_images             1.000000    0.104473    0.115110  0.099288
# last_price               0.104473    1.000000    0.653654  0.363343
# total_area               0.115110    0.653654    1.000000  0.758347
# rooms                    0.099288    0.363343    0.758347  1.000000
# ceiling_height           0.008779    0.081144    0.104419  0.075568
# floors_total             0.014896   -0.007094   -0.075862 -0.225959
# living_area              0.129812    0.491367    0.792508  0.745264
# floor                    0.031340    0.026576   -0.024955 -0.150862
# studio                  -0.029303   -0.025362   -0.072580 -0.147286
# open_plan               -0.024407   -0.008802   -0.034785 -0.087500
# kitchen_area             0.134964    0.388754    0.516350  0.256736
# balcony                  0.048903    0.008559    0.009833 -0.015519
# airports_nearest         0.039937    0.108022    0.091165  0.047542
# ...

# %%
#Также изучите зависимость от даты размещения: дня недели, месяца и года.
data[['Year','month','day']].corrwith(data['price_per_m2'])
# Out:
# Year     0.009775
# month   -0.001996
# day      0.012358
# dtype: float64

# %%
data['Year'].value_counts()
# Out:
# 2018    8519
# 2017    8190
# 2019    2879
# 2016    2783
# 2015    1191
# 2014     137
# Name: Year, dtype: int64

# %% [markdown]
# нет прямой зависимости цены и времени. не наблюдается существенного изменения цен во времени, периуда 2014-2018 годов

# %%
# Изучите зависимость цены от того, на каком этаже расположена квартира: первом, последнем или другом
data_floor = data.pivot_table(index = 'floor_variants', values = 'price_per_m2', aggfunc = ['mean','count','median'])

# %%
data_floor.columns = ['mean','count','median']

# %%
display(data_floor)
# Out:
#                         mean  count        median
# floor_variants
# другой          99931.675830  23673  95454.545455
# первый          46003.431866     25  37000.000000
# последний       84444.444444      1  84444.444444

# %%
data_floor.plot()
# Out:
# <AxesSubplot:xlabel='floor_variants'>

# %% [markdown]
# на первом и последнем этаже, если жить на первом этаже цена два раза ниже;

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Комментарий ревьюера✅:</b> Тут все верно. Корреляция рассчитана, все параметры изучены, графики огонь🔥, вывод на месте, молодец👍

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Комментарий ревьюера⚠️:</b> Хотелось бы больше выводов

# %% [markdown]
# - Выберите 10 населённых пунктов с наибольшим числом объявлений. Посчитайте среднюю цену квадратного метра в этих населённых пунктах. Выделите населённые пункты с самой высокой и низкой стоимостью жилья. Эти данные можно найти по имени в столбце locality_name.

# %%
pd.set_option('display.max_columns', None)
data.head(20)
# Out:
#     total_images  last_price  total_area first_day_exposition  rooms  \
# 0             20    13000000         108           2019-03-07      3
# 1              7     3350000          40           2018-12-04      1
# 2             10     5196000          56           2015-08-20      2
# 3              0    64900000         159           2015-07-24      3
# 4              2    10000000         100           2018-06-19      2
# 5             10     2890000          30           2018-09-10      1
# 6              6     3700000          37           2017-11-02      1
# 7              5     7915000          71           2019-04-18      2
# 8             20     2900000          33           2018-05-23      1
# 9             18     5400000          61           2017-02-26      3
# 10             5     5050000          39           2017-11-16      1
# 11             9     3300000          44           2018-08-27      2
# 12            10     3890000          54           2016-06-30      2
# ...

# %%
# убераю все количественные значения если они есть...
data['only_locality_name']=data['locality_name'].loc[pd.to_numeric(data['locality_name'], errors='coerce').isnull()]

# %%
display(data)
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 0                20    13000000         108           2019-03-07      3
# 1                 7     3350000          40           2018-12-04      1
# 2                10     5196000          56           2015-08-20      2
# 3                 0    64900000         159           2015-07-24      3
# 4                 2    10000000         100           2018-06-19      2
# ...             ...         ...         ...                  ...    ...
# 23694             9     9700000         133           2017-03-21      3
# 23695            14     3100000          59           2018-01-15      3
# 23696            18     2500000          56           2018-02-11      2
# 23697            13    11475000          76           2017-03-28      2
# 23698             4     1350000          32           2017-07-21      1
#
#        ceiling_height  floors_total  living_area  floor is_apartment  studio  \
# ...

# %%
data['only_locality_name'].value_counts().head(20)
# Out:
# Санкт-Петербург            15721
# посёлок Мурино               522
# посёлок Шушары               440
# Всеволожск                   398
# Пушкин                       369
# Колпино                      338
# посёлок Парголово            327
# Гатчина                      307
# деревня Кудрово              299
# Выборг                       237
# Петергоф                     201
# Сестрорецк                   183
# Красное Село                 178
# Кудрово                      173
# деревня Новое Девяткино      144
# Сертолово                    142
# Ломоносов                    133
# Кириши                       125
# Сланцы                       112
# Волхов                       111
# Name: only_locality_name, dtype: int64

# %%
data['only_locality_name'].str.split(expand = True)[0].head(10)
# Out:
# 0    Санкт-Петербург
# 1            посёлок
# 2    Санкт-Петербург
# 3    Санкт-Петербург
# 4    Санкт-Петербург
# 5          городской
# 6            посёлок
# 7    Санкт-Петербург
# 8            посёлок
# 9    Санкт-Петербург
# Name: 0, dtype: object

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Комментарий студента:</b>
# ☑️ удалил 3 лишние ячейки ниже
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Комментарий ревьюера_v2✅:</b> 😉 </div>

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Комментарий ревьюера⚠️:</b> Лишняя ячейка?

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Комментарий ревьюера⚠️:</b> Лишняя ячейка?

# %%
def new_locality_name(loc_name):
    words = loc_name.split(' ')
    new_name = []
    for word in words:
        if (
            'посе' not in word and
            'посё' not in word and
            'город' not in word and
            'дерев' not in word and
            'село' not in word and
            'садов' not in word and
            'товариществ' not in word and
            'село' not in word and
            'при' not in word and
            'железнодор' not in word and
            'станц' not in word and
            'тип' not in word):
 
            new_name.append(word)
 
    return ' '.join(new_name)

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Комментарий ревьюера⚠️:</b> Лишняя ячейка?

# %%
data['TOP_10_cities'] = data['only_locality_name'].apply(new_locality_name)

# %%
data
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 0                20    13000000         108           2019-03-07      3
# 1                 7     3350000          40           2018-12-04      1
# 2                10     5196000          56           2015-08-20      2
# 3                 0    64900000         159           2015-07-24      3
# 4                 2    10000000         100           2018-06-19      2
# ...             ...         ...         ...                  ...    ...
# 23694             9     9700000         133           2017-03-21      3
# 23695            14     3100000          59           2018-01-15      3
# 23696            18     2500000          56           2018-02-11      2
# 23697            13    11475000          76           2017-03-28      2
# 23698             4     1350000          32           2017-07-21      1
#
#        ceiling_height  floors_total  living_area  floor is_apartment  studio  \
# ...

# %%
Top_10 = data.pivot_table(index = 'TOP_10_cities', values = 'price_per_m2', aggfunc = ['min','max','mean','count','median'])

# %%
data['TOP_10_cities'].fillna('Unknown')
# Out:
# 0        Санкт-Петербург
# 1                 Шушары
# 2        Санкт-Петербург
# 3        Санкт-Петербург
# 4        Санкт-Петербург
#               ...
# 23694    Санкт-Петербург
# 23695              Тосно
# 23696        Рождествено
# 23697    Санкт-Петербург
# 23698        Новый Учхоз
# Name: TOP_10_cities, Length: 23699, dtype: object

# %%
data['TOP_10_cities'].value_counts().head(20)
# Out:
# Санкт-Петербург    15721
# Мурино               590
# Кудрово              472
# Шушары               440
# Всеволожск           398
# Пушкин               369
# Колпино              338
# Парголово            327
# Гатчина              307
# Выборг               237
# Петергоф             201
# Сестрорецк           183
# Красное Село         178
# Новое Девяткино      144
# Сертолово            142
# Ломоносов            133
# Кириши               125
# Бугры                114
# Сланцы               112
# Волхов               111
# Name: TOP_10_cities, dtype: int64

# %%
Top_10.columns = ['min','max','mean','count','median']

# %% [markdown]
#  -Посчитайте среднюю цену квадратного метра в этих населённых пунктах. Выделите населённые пункты с самой высокой и низкой стоимостью жилья.

# %%
TOP_10_cities = Top_10.sort_values('count', ascending = False).iloc[:10]

# %%
#Выберите 10 населённых пунктов с наибольшим числом объявлени и Посчитал среднюю цену квадратного метра в этих населённых пунктах
TOP_10_cities.sort_values('count', ascending = False)
# Out:
#                           min           max           mean  count  \
# TOP_10_cities
# Санкт-Петербург    111.834862  1.907500e+06  115347.722976  15721
# Мурино           50000.000000  1.403125e+05   86729.540028    590
# Кудрово          54336.956522  1.620253e+05   95879.316021    472
# Шушары           47766.666667  1.478261e+05   79068.602928    440
# Всеволожск       31400.000000  6.424447e+05   68985.235455    398
# Пушкин           59836.065574  2.565217e+05  103611.362825    369
# Колпино          48214.285714  1.250000e+05   75735.589833    338
# Парголово        39303.482587  1.418919e+05   90675.627757    327
# Гатчина          10507.246377  1.463158e+05   69045.519030    307
# Выборг           18750.000000  1.074731e+05   58296.119480    237
#
#                         median
# TOP_10_cities
# Санкт-Петербург  105263.157895
# Мурино            86729.559748
# Кудрово           96190.130624
# Шушары            77223.320158
# Всеволожск        65811.403509
# ...

# %%
#Выделите населённые пункты с самой низкой стоимостью жилья 
Top_10.sort_values('min', ascending = True)
# Out:
#                            min           max           mean  count  \
# TOP_10_cities
# Санкт-Петербург     111.834862  1.907500e+06  115347.722976  15721
# Свирь              7962.962963  1.500000e+04   11481.481481      2
# Сланцы             9615.384615  4.333333e+04   18212.902913    112
# Старополье        10465.116279  1.225000e+04   11238.372093      3
# Гатчина           10507.246377  1.463158e+05   69045.519030    307
# ...                        ...           ...            ...    ...
# Старое Хинколово  76470.588235  7.647059e+04   76470.588235      1
# Мистолово         81012.658228  1.530612e+05   99534.563390     11
# Новая Ропша       81081.081081  8.108108e+04   81081.081081      1
# Корнево           86086.956522  8.608696e+04   86086.956522      1
# Левашово          97674.418605  9.767442e+04   97674.418605      1
#
#                          median
# TOP_10_cities
# Санкт-Петербург   105263.157895
# Свирь              11481.481481
# ...

# %%
#Выделите населённые пункты с самой высокой стоимостью жилья
Top_10.sort_values('max', ascending = False)
# Out:
#                           min           max           mean  count  \
# TOP_10_cities
# Санкт-Петербург    111.834862  1.907500e+06  115347.722976  15721
# Всеволожск       31400.000000  6.424447e+05   68985.235455    398
# Зеленогорск      53333.333333  3.239437e+05  115527.923403     24
# Пушкин           59836.065574  2.565217e+05  103611.362825    369
# Петергоф         51612.903226  2.283929e+05   85259.837325    201
# ...                       ...           ...            ...    ...
# Тёсово-4         12931.034483  1.293103e+04   12931.034483      1
# Малая Романовка  12878.787879  1.287879e+04   12878.787879      1
# Совхозный        12555.555556  1.270270e+04   12629.129129      2
# Старополье       10465.116279  1.225000e+04   11238.372093      3
# Вахнова Кара     11842.105263  1.184211e+04   11842.105263      1
#
#                         median
# TOP_10_cities
# Санкт-Петербург  105263.157895
# Всеволожск        65811.403509
# Зеленогорск      101666.666667
# ...

# %% [markdown]
# город с самое большое каличество обявления это Санкт-Петербург, тоже Санкт-Петербург входит в топ самой низкой / высокой стоимостью жилья

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Комментарий ревьюера✅:</b> Тут все верно👍 Я бы предложил отсортировать города по восростанию средней цены и построить bar_plot, это было бы супер наглядно)</div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Комментарий студента:</b>
# ☑️ Интересно, спасибо за совет! сделал ниже
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Комментарий ревьюера_v2✅:</b> Огонь🔥 </div>

# %%
TOP_10_cities['mean'].sort_values(ascending = False).plot(kind= 'bar')
# Out:
# <AxesSubplot:xlabel='TOP_10_cities'>

# %%
Top_10.sort_values(by = 'mean', ascending = False)
# Out:
#                           min           max           mean  count  \
# TOP_10_cities
# Зеленогорск      53333.333333  3.239437e+05  115527.923403     24
# Санкт-Петербург    111.834862  1.907500e+06  115347.722976  15721
# Репино           69171.350000  1.750000e+05  104313.941396      4
# Пушкин           59836.065574  2.565217e+05  103611.362825    369
# Сестрорецк       50434.782609  1.826882e+05  102182.271293    183
# ...                       ...           ...            ...    ...
# Совхозный        12555.555556  1.270270e+04   12629.129129      2
# Выскатка         11463.414634  1.320755e+04   12335.480902      2
# Вахнова Кара     11842.105263  1.184211e+04   11842.105263      1
# Свирь             7962.962963  1.500000e+04   11481.481481      2
# Старополье       10465.116279  1.225000e+04   11238.372093      3
#
#                         median
# TOP_10_cities
# Зеленогорск      101666.666667
# Санкт-Петербург  105263.157895
# Репино            86542.207792
# ...

# %% [markdown]
#     -  «Изучите предложения квартир: для каждой квартиры есть информация о расстоянии до центра. Выделите квартиры в Санкт-Петербурге (locality_name). Ваша задача — выяснить, какая область входит в центр. Создайте столбец с расстоянием до центра в километрах: округлите до целых значений. После этого посчитайте среднюю цену для каждого километра. Постройте график: он должен показывать, как цена зависит от удалённости от центра. Определите границу, где график сильно меняется — это и будет центральная зона».

# %%
display(data)
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 0                20    13000000         108           2019-03-07      3
# 1                 7     3350000          40           2018-12-04      1
# 2                10     5196000          56           2015-08-20      2
# 3                 0    64900000         159           2015-07-24      3
# 4                 2    10000000         100           2018-06-19      2
# ...             ...         ...         ...                  ...    ...
# 23694             9     9700000         133           2017-03-21      3
# 23695            14     3100000          59           2018-01-15      3
# 23696            18     2500000          56           2018-02-11      2
# 23697            13    11475000          76           2017-03-28      2
# 23698             4     1350000          32           2017-07-21      1
#
#        ceiling_height  floors_total  living_area  floor is_apartment  studio  \
# ...

# %%
len(data)
# Out:
# 23699

# %%
data['cityCenters_nearest'].describe()
# Out:
# count    23699.000000
# mean     10886.426896
# std       9634.613697
# min          0.000000
# 25%       2242.000000
# 50%      11247.000000
# 75%      15248.500000
# max      65968.000000
# Name: cityCenters_nearest, dtype: float64

# %%
# очень много значения "0", это может значить нет данных или находятся прямо в центр... остовляю 165 значкния как есть так как не играет большую роль в моем анаоизе, особенно в табличке St_Petersburg
len(data[data['cityCenters_nearest']==0])
# Out:
# 5519

# %%
# Выделите квартиры в Санкт-Петербурге (locality_name).
data['st_petersburg'] = data['TOP_10_cities']=='Санкт-Петербург'

# %%
#Создайте столбец с расстоянием до центра в километрах: округлите до целых значений.
data['distance_center_km'] = round(data['cityCenters_nearest']/1000,0)

# %%
data['distance_center_km'] = data['distance_center_km'].astype('int',errors='ignore')

# %%
pd.to_numeric(data['distance_center_km'],errors = 'coerce')
# Out:
# 0        16
# 1        19
# 2        14
# 3         7
# 4         8
#          ..
# 23694     4
# 23695     0
# 23696     0
# 23697    10
# 23698     0
# Name: distance_center_km, Length: 23699, dtype: int32

# %%
#посчитайте среднюю цену для каждого километра. 
data['average_price_per_km'] = round(data['last_price'] / data['distance_center_km'],0)

# %%
data['average_price_per_km'] = data['average_price_per_km'].astype('int',errors='ignore')

# %%
pd.to_numeric(data['average_price_per_km'],errors = 'coerce')
# Out:
# 0         812500.0
# 1         176316.0
# 2         371143.0
# 3        9271429.0
# 4        1250000.0
#            ...
# 23694    2425000.0
# 23695          inf
# 23696          inf
# 23697    1147500.0
# 23698          inf
# Name: average_price_per_km, Length: 23699, dtype: float64

# %%
# фильтрую только Санкт-Петербург
st_petersburg = data.query('TOP_10_cities=="Санкт-Петербург"')

# %%
st_petersburg
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 0                20    13000000         108           2019-03-07      3
# 2                10     5196000          56           2015-08-20      2
# 3                 0    64900000         159           2015-07-24      3
# 4                 2    10000000         100           2018-06-19      2
# 7                 5     7915000          71           2019-04-18      2
# ...             ...         ...         ...                  ...    ...
# 23689            13     3550000          35           2018-02-28      1
# 23690             3     5500000          52           2018-07-19      2
# 23691            11     9470000          72           2016-10-13      2
# 23694             9     9700000         133           2017-03-21      3
# 23697            13    11475000          76           2017-03-28      2
#
#        ceiling_height  floors_total  living_area  floor is_apartment  studio  \
# ...

# %%
import numpy as np

# %%
st_petersburg.replace([np.inf, -np.inf],np.nan,inplace=True)
# Out:
# C:\Users\corneliu.leahu\Anaconda3\lib\site-packages\pandas\core\frame.py:5238: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().replace(

# %%
st_petersburg.dropna(subset=["distance_center_km", "average_price_per_km"], how="all",inplace=True)
# Out:
# C:\Users\corneliu.leahu\Anaconda3\lib\site-packages\pandas\util\_decorators.py:311: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return func(*args, **kwargs)

# %%
st_petersburg.describe()
# Out:
#        total_images    last_price    total_area         rooms  ceiling_height  \
# count  15721.000000  1.572100e+04  15721.000000  15721.000000    15721.000000
# mean      10.180205  8.062507e+06     64.522422      2.171618        2.177279
# std        5.749004  1.301313e+07     40.430343      1.148098        1.091166
# min        0.000000  1.219000e+04     12.000000      0.000000        1.000000
# 25%        6.000000  4.200000e+06     42.000000      1.000000        2.000000
# 50%       10.000000  5.500000e+06     55.000000      2.000000        2.000000
# 75%       14.000000  8.160000e+06     74.000000      3.000000        2.000000
# max       50.000000  7.630000e+08    900.000000     19.000000      100.000000
#
#        floors_total   living_area         floor  kitchen_area       balcony  \
# count  15721.000000  15721.000000  15721.000000  15721.000000  15721.000000
# mean      11.345143     34.045544      6.242033      9.948858      0.581770
# ...

# %%
st_petersburg.describe()
# Out:
#        total_images    last_price    total_area         rooms  ceiling_height  \
# count  15721.000000  1.572100e+04  15721.000000  15721.000000    15721.000000
# mean      10.180205  8.062507e+06     64.522422      2.171618        2.177279
# std        5.749004  1.301313e+07     40.430343      1.148098        1.091166
# min        0.000000  1.219000e+04     12.000000      0.000000        1.000000
# 25%        6.000000  4.200000e+06     42.000000      1.000000        2.000000
# 50%       10.000000  5.500000e+06     55.000000      2.000000        2.000000
# 75%       14.000000  8.160000e+06     74.000000      3.000000        2.000000
# max       50.000000  7.630000e+08    900.000000     19.000000      100.000000
#
#        floors_total   living_area         floor  kitchen_area       balcony  \
# count  15721.000000  15721.000000  15721.000000  15721.000000  15721.000000
# mean      11.345143     34.045544      6.242033      9.948858      0.581770
# ...

# %% [markdown]
# -Постройте график: он должен показывать, как цена зависит от удалённости от центра. Определите границу, где график сильно меняется, — это и будет центральная зона.

# %%
st_petersburg.sort_values('average_price_per_km').plot(x = 'distance_center_km', y = 'average_price_per_km', kind='scatter',figsize=(16, 6))
# Out:
# <AxesSubplot:xlabel='distance_center_km', ylabel='average_price_per_km'>

# %%
st_petersburg.plot(x = 'distance_center_km', y = 'average_price_per_km',figsize=(16,6))
# Out:
# <AxesSubplot:xlabel='distance_center_km'>

# %%
st_petersburg.sort_values('distance_center_km').plot(x = 'distance_center_km', y = 'average_price_per_km',figsize=(16,6))
# Out:
# <AxesSubplot:xlabel='distance_center_km'>

# %% [markdown]
# исходя из этих вух графиков высше, можно обозначить уже границу, где график сущесвенно меняется меняется, чтобы обозначить уже центральню зону ('distance_center_km' < 8 KM)

# %%
#было так раньше, но неправельно 
#st_petersburg.sort_values('price_per_m2').plot(x = 'distance_center_km', y = 'price_per_m2', kind='scatter')

# %%
#было так раньше, но неправельно 
#st_petersburg.sort_values('price_per_m2').plot(x = 'distance_center_km', y = 'price_per_m2')

# %%
st_petersburg['average_price_per_km'].value_counts().sort_values(ascending = False).head(10)
# Out:
# 300000.0    144
# 500000.0    109
# 350000.0    101
# 400000.0     97
# 325000.0     69
# 333333.0     62
# 250000.0     62
# 375000.0     58
# 450000.0     53
# 200000.0     52
# Name: average_price_per_km, dtype: int64

# %%
st_petersburg['average_price_per_km'].describe()
# Out:
# count    1.563300e+04
# mean     1.370571e+06
# std      5.745353e+06
# min      1.354000e+03
# 25%      3.083330e+05
# 50%      4.488460e+05
# 75%      9.984620e+05
# max      3.300000e+08
# Name: average_price_per_km, dtype: float64

# %%
st_petersburg['distance_center_km'].value_counts().sort_values(ascending=False).head(10)
# Out:
# 12    1605
# 15    1568
# 13    1457
# 14    1279
# 16    1265
# 11    1178
# 5      920
# 17     883
# 10     719
# 4      688
# Name: distance_center_km, dtype: int64

# %%
st_petersburg['distance_center_km'].describe()
# Out:
# count    15721.000000
# mean        11.551046
# std          4.907395
# min          0.000000
# 25%          8.000000
# 50%         12.000000
# 75%         15.000000
# max         29.000000
# Name: distance_center_km, dtype: float64

# %% [markdown]
# Я все таки склонен сказать что центраоьная зоня является в радиусе 15KM от центра

# %% [markdown]
# - Выделите сегмент квартир в центре. Проанализируйте эту территорию и изучите следующие параметры: площадь, цена, число комнат, высота потолков. Также выделите факторы, которые влияют на стоимость квартиры (число комнат, этаж, удалённость от центра, дата размещения объявления). Сделайте выводы. Отличаются ли они от общих выводов по всей базе?

# %%
#Определите границу, где график сильно меняется, — это и будет центральная зона.
#st_petersburg_center_zone = st_petersburg.query('price_per_m2 <=250000 and distance_center_km<15')

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>Комментарий ревьюера❌:</b> Не совсем согласен с выделением центра. Во первых мы должны его выделить только на основе расстояния, по цене центр города определять не совсем корректно. Предлагаю определить центр города по алгоритму, который указан в задании:
#
# Создайте столбец с расстоянием до центра в километрах: округлите до целых значений. После этого посчитайте среднюю цену для каждого километра. Постройте график: он должен показывать, как цена зависит от удалённости от центра. Определите границу, где график сильно меняется, — это и будет центральная зона.

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Комментарий студента:</b>
# ☑️ я правельно понимаю: среднюю цену для каждого километра это 'last_price' / 'distance_center_km, если так то выше дольжно быть правильно в этот раз
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Комментарий студента:</b>
# ☑️  исправил графики высше и свои выводы
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Комментарий студента:</b>
# ☑️  поменфл центраоьную зону ниже: distance_center_km<8
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Комментарий ревьюера_v2✅:</b> Теперь согласен, граница выделена верно👍 </div>

# %% [markdown]
# я правельно понимаю: среднюю цену для каждого километра это 'last_price' / 'distance_center_km, если так то выше дольжно быть правильно в этот раз

# %%
st_petersburg_center_zone = st_petersburg.query('distance_center_km<8')

# %%
st_petersburg_center_zone.plot(y = 'average_price_per_km', x = 'distance_center_km')
# Out:
# <AxesSubplot:xlabel='distance_center_km'>

# %%
st_petersburg_center_zone.plot(y = 'average_price_per_km', x = 'distance_center_km', kind = 'scatter')
# Out:
# <AxesSubplot:xlabel='distance_center_km', ylabel='average_price_per_km'>

# %%
# чем дальше от росстояния от цетра , тем меньше цена квадратенрго метра... 
st_petersburg_center_zone['average_price_per_km'].corr(st_petersburg['distance_center_km'])
# Out:
# -0.28261486215082804

# %%
#обявления ниже необычно дорогие,или можно их считать аномалии или  мошенническую деятельность. список:
st_petersburg[st_petersburg['price_per_m2']>250000]
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 3                 0    64900000         159           2015-07-24      3
# 51                7    45000000         161           2017-10-17      3
# 155               8    96000000         317           2017-07-07      4
# 263              12    39900000         140           2016-11-19      2
# 282              17    37000000         115           2018-11-15      2
# ...             ...         ...         ...                  ...    ...
# 22898             1    21821800          76           2019-04-01      1
# 22907             9    65000000         228           2016-06-02      4
# 22948            10    34500000         100           2018-06-26      3
# 23185            18    24500000          93           2017-11-01      2
# 23574            14    64990000         139           2015-11-24      3
#
#        ceiling_height  floors_total  living_area  floor is_apartment  studio  \
# ...

# %% [markdown]
#     - Также выделите факторы, которые влияют на стоимость квартиры (число комнат, этаж, удалённость от центра, дата размещения объявления)

# %%
data_corr_2 = pd.DataFrame(data=st_petersburg_center_zone, columns = ['rooms','floors_total','price_per_m2','distance_center_km','first_day_exposition'])

# %%
data_corr_2.corr()
# Out:
#                        rooms  floors_total  price_per_m2  distance_center_km
# rooms               1.000000     -0.194665     -0.004540           -0.131254
# floors_total       -0.194665      1.000000      0.108157            0.295529
# price_per_m2       -0.004540      0.108157      1.000000           -0.024806
# distance_center_km -0.131254      0.295529     -0.024806            1.000000

# %%
pd.plotting.scatter_matrix(data_corr_2,figsize=(9, 9))
# Out:
# array([[<AxesSubplot:xlabel='rooms', ylabel='rooms'>,
#         <AxesSubplot:xlabel='floors_total', ylabel='rooms'>,
#         <AxesSubplot:xlabel='price_per_m2', ylabel='rooms'>,
#         <AxesSubplot:xlabel='distance_center_km', ylabel='rooms'>],
#        [<AxesSubplot:xlabel='rooms', ylabel='floors_total'>,
#         <AxesSubplot:xlabel='floors_total', ylabel='floors_total'>,
#         <AxesSubplot:xlabel='price_per_m2', ylabel='floors_total'>,
#         <AxesSubplot:xlabel='distance_center_km', ylabel='floors_total'>],
#        [<AxesSubplot:xlabel='rooms', ylabel='price_per_m2'>,
#         <AxesSubplot:xlabel='floors_total', ylabel='price_per_m2'>,
#         <AxesSubplot:xlabel='price_per_m2', ylabel='price_per_m2'>,
#         <AxesSubplot:xlabel='distance_center_km', ylabel='price_per_m2'>],
#        [<AxesSubplot:xlabel='rooms', ylabel='distance_center_km'>,
#         <AxesSubplot:xlabel='floors_total', ylabel='distance_center_km'>,
# ...

# %%
st_petersburg_center_zone[['rooms','floors_total','distance_center_km','days_exposition']].corrwith(data['price_per_m2'])
# Out:
# rooms                -0.004540
# floors_total          0.108157
# distance_center_km   -0.024806
# days_exposition       0.001740
# dtype: float64

# %% [markdown]
# данные достаточно диверсифицировано распределены.
# мы видим что корелация отрицательная -стоимисти и каличество комнат- , но это логично, чем больше комнат, тем больше площадь, тем меньше стоимость кводратного метра. То же самое мы мы наблюдаем и по отдолености от центра, чем дальше от центра - тем дешевле и больше этажемость.

# %% [markdown]
#     - Проанализируйте эту территорию и изучите следующие параметры: площадь, цена, число комнат, высота потолков.

# %%
st_petersburg_center_zone['total_area'].hist()
# Out:
# <AxesSubplot:>

# %%
st_petersburg_center_zone['distance_center_km'].hist()
# Out:
# <AxesSubplot:>

# %%
st_petersburg_center_zone['rooms'].hist()
# Out:
# <AxesSubplot:>

# %%
st_petersburg_center_zone['ceiling_height'].hist(range = (2,5))
# Out:
# <AxesSubplot:>

# %% [markdown]
#     - Сделайте выводы. Отличаются ли они от общих выводов по всей базе?

# %% [markdown]
# в питере отличаются данные в сровнение с общих данных из датасета. мы можем наблюдать что в основном в Питере квартипы с площадю до 100М2, и приевосходства имеют маленкие квартиры. Такая иенденцтя наблюдается и с общими данными. Соотвественно квартиры с одной или 2мя -комнат, и чуть меньше 3х комнатные. Высота потолков в оновном 2 И 3 метра, в сравнения с общими данные. В то же время, диапозон цен в Питере 50К-200К (100K  цена ориентир) что меньше чем в общию базу данных

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Комментарий ревьюера✅:</b> Все параметры изучены, графики построены, выводы написаны, молодец🔥🔥🔥

# %% [markdown]
# ## Общий вывод

# %% [markdown]
# Санкт-Петербург – Город с самыми высокими ценнами на недвижисомть, а также находим самое большое каличество обявления. Цена-оброзования  конечно зависит от одалености от ценртра и от площади. Еще один интересный актор, это зовисимость этажность здании от  одалености от ценртра.
# Варияция цен в  Санкт-Петербург большая, мы видим средняя цена намного ниже чем медииан в сравнение с другими городами, потому я сделал короткий список обьектов которы входят в категорию потонцеалное мошенничество.
# В целом мы видим логический тренд: чем ближе ук центру, тем выше стоимость кводоаеного метра.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Комментарий ревьюера✅:</b> Отличный вывод, теперь работа логчески завершена и мы можем понять суть исследования🔥</div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Комментарий ревьюера✅:</b>Мне очень понравилась твоя работа. Все рассуждения верные, очень логичные и осмысленные. Ничего лишнего, всё по полкам. Ты подробно разбираешься в деталях, для будущего аналитика это очень важная черта😊
#
# Проект еще нужно немного доработать, а именно:
#
# - добавить вывод в блок изучения распределений
#
# - исправить выделение центра города
#
# Остальные замечания оставляю на твое усмотрение😉
#
# Жду твою работу на повторное ревью.
#
# [Интересная статья про визуализацию](https://habr.com/ru/company/netologyru/blog/341364/)
#
# [Тут есть полезные приемы Markdown](https://paulradzkov.com/2014/markdown_cheatsheet/)
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Комментарий ревьюера_v2✅:</b> Отличная работа, проект принимаю. Могу с уверенностью сказать - ты хорошо владеешь пройденным материалом. Мне понравилась твоя реакция на обратную связь, комментарии даже к желтым замечаниям. Желаю удачи в дальнейшей учебе🔥 </div>

# %% [markdown]
# ## Чек-лист готовности проекта
#
# Поставьте 'x' в выполненных пунктах. Далее нажмите Shift+Enter.

# %% [markdown]
# - [x]  открыт файл
# - [ ]  файлы изучены (выведены первые строки, метод `info()`)
# - [ ]  определены пропущенные значения
# - [ ]  заполнены пропущенные значения
# - [ ]  есть пояснение, какие пропущенные значения обнаружены
# - [ ]  изменены типы данных
# - [ ]  есть пояснение, в каких столбцах изменены типы и почему
# - [ ]  посчитано и добавлено в таблицу: цена квадратного метра
# - [ ]  посчитано и добавлено в таблицу: день недели, месяц и год публикации объявления
# - [ ]  посчитано и добавлено в таблицу: этаж квартиры; варианты — первый, последний, другой
# - [ ]  посчитано и добавлено в таблицу: соотношение жилой и общей площади, а также отношение площади кухни к общей
# - [ ]  изучены следующие параметры: площадь, цена, число комнат, высота потолков
# - [ ]  построены гистограммы для каждого параметра
# - [ ]  выполнено задание: «Изучите время продажи квартиры. Постройте гистограмму. Посчитайте среднее и медиану. Опишите, сколько обычно занимает продажа. Когда можно считать, что продажи прошли очень быстро, а когда необычно долго?»
# - [ ]  выполнено задание: «Уберите редкие и выбивающиеся значения. Опишите, какие особенности обнаружили».
# - [ ]  выполнено задание: «Какие факторы больше всего влияют на стоимость квартиры? Изучите, зависит ли цена от квадратного метра, числа комнат, этажа (первого или последнего), удалённости от центра. Также изучите зависимость от даты размещения: дня недели, месяца и года».
# - [ ]  выполнено задание: «Выберите 10 населённых пунктов с наибольшим числом объявлений. Посчитайте среднюю цену квадратного метра в этих населённых пунктах. Выделите населённые пункты с самой высокой и низкой стоимостью жилья. Эти данные можно найти по имени в столбце `locality_name`».
# - [ ]  выполнено задание: «Изучите предложения квартир: для каждой квартиры есть информация о расстоянии до центра. Выделите квартиры в Санкт-Петербурге (`locality_name`). Ваша задача — выяснить, какая область входит в центр. Создайте столбец с расстоянием до центра в километрах: округлите до целых значений. После этого посчитайте среднюю цену для каждого километра. Постройте график: он должен показывать, как цена зависит от удалённости от центра. Определите границу, где график сильно меняется — это и будет центральная зона».
# - [ ]  выполнено задание: «Выделите сегмент квартир в центре. Проанализируйте эту территорию и изучите следующие параметры: площадь, цена, число комнат, высота потолков. Также выделите факторы, которые влияют на стоимость квартиры (число комнат, этаж, удалённость от центра, дата размещения объявления). Сделайте выводы. Отличаются ли они от общих выводов по всей базе?»
# - [ ]  в каждом этапе есть выводы
# - [ ]  есть общий вывод
