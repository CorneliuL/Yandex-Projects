# %% [markdown]
# <div style="border:solid Chocolate 2px; padding: 40px">
#
# <b> Привет!👋</b>
#
# Меня зовут Алексей Гриб, и я буду ревьюером твоего проекта.
#
# Буду рад, если и ты представишься - в тикет проекта не подтянулось твоё имя, поэтому буд рад сделать наше общение более личным:)
#
# Сразу хочу предложить в дальнейшем общаться на "ты" - надеюсь, так будет комфортнее:) Но если это неудобно, обязательно дай знать, и мы придумаем что-нибудь ещё!
#
# Цель ревью - не искать ошибки в твоём проекте, а помочь тебе сделать твою работу ещё лучше, устранив недочёты и приблизив её к реальным задачам аналитика. Поэтому не расстраивайся, если что-то не получилось с первого раза - это нормально, и это поможет тебе вырасти!
#
# Ты можешь найти мои комментарии, обозначенные <font color='green'>зеленым</font>, <font color='gold'>желтым</font> и <font color='red'>красным</font> цветами, например:
#
# <br/>
#
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> похвала, рекомендации «со звёздочкой», полезные лайфхаки, которые сделают и без того красивое решение ещё более элегантным.
# </div>
#
# <br/>
#
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации⚠️:</b> некритичные ошибки или развивающие рекомендации на будущее.
# </div>
#
#
# <br/>
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b>
# Критичные ошибки, которые обязательно нужно исправить.
# </div>
#
# Я не смогу принять проект, если в нём будет хотя бы одна критичная ошибка или несколько некритичных ошибок - тогда проект нужно будет немного доработать. Но это нестрашно - я обязательно дам тебе подсказку или укажу верное направление.
#
# Пожалуйста, не удаляй мои комментарии, они будут особенно полезны для нашей работы в случае повторной проверки проекта.
#
# Ты также можешь задавать свои вопросы, реагировать на мои комментарии, делать пометки и пояснения - полная творческая свобода! Но маленькая просьба - пускай они будут отличаться от моих комментариев, это поможет избежать путаницы в нашем общении:)
# Например, вот так:
#
# <div class="alert alert-info">
# <h2> Комментарий студента <a class="tocSkip"> </h2>
#
# *твой текст*
# </div>
#
# Давай посмотрим на твой проект!

# %% [markdown]
# # "Проект по SQL"

# %% [markdown]
# # Описание проекта
#
# `Моя задача:`
#
#     Моя компания решила быть на волне и купила крупный сервис для чтения книг по подписке.
#     Моя основная задача — проанализировать базу данных. В ней информация о книгах, издательствах, авторах, а также пользовательские обзоры книг.
#
# `Моя цель:`
#
#     Сформулировать ценностное предложение для нового продукта.
#
# `Шаги для выполнения задачи проекта:`
#
#     - Посчитаю, сколько книг вышло после 1 января 2000 года;
#     - Для каждой книги посчитаю количество обзоров и среднюю оценку;
#     - Определю издательство, которое выпустило наибольшее число книг толще 50 страниц — так вы исключите из анализа брошюры;
#     - Определю автора с самой высокой средней оценкой книг — учитывайте только книги с 50 и более оценками;
#     - Посчитаю среднее количество обзоров от пользователей, которые поставили больше 50 оценок.
#
# `Описание данных:`
#
# ![image.png](attachment:image.png)

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b>
# В твоём проекте практически отсутствует вступление: это очень важная часть проекта, которая задаёт, так сказать, весь тон дальнейшей работы и помогает читателю быстро понять суть того, что происходило в проекте - не стоит ею пренебрегать.
#
# Хорошее вступление должно содержать следующие элементы:
# - название проекта (наш так и называется - "Проект по SQL"); <a id='## - Посчитайте, сколько книг вышло после 1 января 2000 года;'></a>
# - цель проекта (что-то глобальное, ради чего делаем проект - нужно сформулировать самостоятельно);
# - задачи проекта (маленькие шаги по достижению цели проекта, в нашем проекте это могут быть вопросы, на которые ты отвечаешь);
# - описание данных (можно также скопировать из вводной части);
# - оглавление, оно же план работы (материал об этом есть в блоке курса Полезные инструкции для учёбы - Оформление проекта - Изменения в Jupyter: автоматическое оглавление и горячие клавиши, либо ты можешь использовать гиперссылки - подробнее об их применении можно прочитать тут: https://sebastianraschka.com/Articles/2014_ipython_internal_links.html).
#
# Постарайся, пожалуйста, учесть все пукнты из этого комментария на следующей итерации работы над проектом.
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <h2> Комментарий студента <a class="tocSkip"> </h2>
#
# сапсибо Алексей! добавил выше все необходимые элементы для вступление.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v.2 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Учтено!
#
# </div>

# %%
# импортируем библиотеки
import pandas as pd
from sqlalchemy import create_engine

# %%
# устанавливаем параметры
db_config = {'user': 'praktikum_student', # имя пользователя
'pwd': 'Sdf4$2;d-d30pp', # пароль
'host': 'rc1b-wcoijxj3yxfsf3fs.mdb.yandexcloud.net',
'port': 6432, # порт подключения
'db': 'data-analyst-final-project-db'} # название базы данных
connection_string = 'postgresql://{}:{}@{}:{}/{}'.format(db_config['user'],
db_config['pwd'],
db_config['host'],
db_config['port'],
db_config['db'])

# сохраняем коннектор
engine = create_engine(connection_string, connect_args={'sslmode':'require'})

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Библиотеки импортировали, коннектор сделали - отлично!
#
# Спасибо, что перезапускаешь ядро проекта перед отправкой на ревью - это важный шаг, который поможет избежать простых и досадных ошибок при воспроизведении решнеия:)
# </div>

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации⚠️:</b>
# Блок загрузки библиотек лучше размещать в отдельной от остального кода ячейке. Такой подход позволит улучшить читаемость кода, снизит время поиска ошибок (если они есть) и исключит повторное выполнение кода.
#         </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v.2 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Учтено!
#
# </div>

# %% [markdown]
# # Задания

# %% [markdown]
# ## - Посчитайте, сколько книг вышло после 1 января 2000 года;

# %%
query_1 = ''' SELECT 
           COUNT(book_id)
            FROM books
            wHERE CAST(publication_date as date)>'2000-01-01'
   
            '''
    
pd.io.sql.read_sql(query_1, con = engine)
# Out:
#    count
# 0    819

# %% [markdown]
# коментарии:
# 819 книг вышло после 1 января 2000 года

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Правильно!
#
# Отмечу, что условие фильтрации `publication_date >= '2000-01-01' ` также было бы правильным, хоть и привело бы к другому результату - в реальных проектах о том, включается ли дата в диапазон или нет, всегда стоит уточнять заранее:)
#
# </div>

# %% [markdown]
# ## Для каждой книги посчитайте количество обзоров и среднюю оценку;

# %%
query_2 = ''' 

SELECT 
    b.book_id,
    b.title as individual_book,
    COUNT(rev.review_id) as count_reviews,
    ROUND(AVG(rat.rating),2) as mean_rating
FROM books as b
RIGHT JOIN reviews as rev on b.book_id = rev.book_id
LEFT JOIN ratings as rat on rev.book_id = rat.book_id            
GROUP BY b.book_id
ORDER BY count_reviews DESC
LIMIT 10;
            '''
    
pd.io.sql.read_sql(query_2, con = engine)
# Out:
#    book_id                                    individual_book  count_reviews  \
# 0      948                            Twilight (Twilight  #1)           1120
# 1      750                The Hobbit  or There and Back Again            528
# 2      673                             The Catcher in the Rye            516
# 3      302  Harry Potter and the Prisoner of Azkaban (Harr...            492
# 4      299  Harry Potter and the Chamber of Secrets (Harry...            480
# 5       75               Angels & Demons (Robert Langdon  #1)            420
# 6      301  Harry Potter and the Order of the Phoenix (Har...            375
# 7      779  The Lightning Thief (Percy Jackson and the Oly...            372
# 8      722  The Fellowship of the Ring (The Lord of the Ri...            370
# 9       79                                        Animal Farm            370
#
#    mean_rating
# 0         3.66
# 1         4.13
# 2         3.83
# 3         4.41
# 4         4.29
# 5         3.68
# ...

# %%
query_2 = ''' 

SELECT 
    b.book_id,
    b.title as individual_book,
    COUNT(rev.review_id) as count_reviews,
    ROUND(AVG(rat.rating),2) as mean_rating
FROM books as b
RIGHT JOIN reviews as rev on b.book_id = rev.book_id
RIGHT JOIN ratings as rat on b.book_id = rat.book_id            
GROUP BY b.book_id
ORDER BY count_reviews DESC
LIMIT 10;
            '''
    
pd.io.sql.read_sql(query_2, con = engine)
# Out:
#    book_id                                    individual_book  count_reviews  \
# 0      948                            Twilight (Twilight  #1)           1120
# 1      750                The Hobbit  or There and Back Again            528
# 2      673                             The Catcher in the Rye            516
# 3      302  Harry Potter and the Prisoner of Azkaban (Harr...            492
# 4      299  Harry Potter and the Chamber of Secrets (Harry...            480
# 5       75               Angels & Demons (Robert Langdon  #1)            420
# 6      301  Harry Potter and the Order of the Phoenix (Har...            375
# 7      779  The Lightning Thief (Percy Jackson and the Oly...            372
# 8      722  The Fellowship of the Ring (The Lord of the Ri...            370
# 9       79                                        Animal Farm            370
#
#    mean_rating
# 0         3.66
# 1         4.13
# 2         3.83
# 3         4.41
# 4         4.29
# 5         3.68
# ...

# %% [markdown]
#     Топ 10 книг по количество обзоров получили средние оценки между 3.60-4.40. Не всегда самые популярные книги по количеству обзора получают высокую средняю оценку. Это случае с  книгой "Twilight (Twilight 1)", которая нобрала 1120 обзоров и получила достаточно низкую оценку 3.66

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b>
# Ответ не совсем верный - получилось многовато оценок. Обрати, пожалуйста, внимание, что для фильма `Twilight (Twilight  #1)` у тебя 1120 оценок. Сравни эту цифру с исходными данными в таблице `reviews` - будет ли количество оценок таким же?
#
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <h2> Комментарий студента <a class="tocSkip"> </h2>
#
# сапсибо!
#
# я сравнил 1120 оценок с исходными данными в таблице reviews и понял что у меня ошибка, максимум оценок это 7.
#
# ниже сделал правильно и поменял коментарии.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v.2 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Учтено!
#
# </div>

# %%
query_2 = ''' 

WITH

a as 

(SELECT 
   book_id,
   COUNT(DISTINCT(review_id)) as count_review
FROM reviews
GROUP BY book_id),

b as 
(SELECT 
   book_id,
   AVG(rating) as rating_mean
FROM ratings
GROUP BY book_id),

c as
(SELECT 
   book_id,
   title
FROM books)

SELECT
    c.book_id,
    c.title,
    a.count_review,
    ROUND(b.rating_mean,2)

FROM a 
JOIN b ON a.book_id = b.book_id
JOIN c ON  b.book_id = c.book_id
ORDER BY a.count_review DESC
LIMIT 20;

            '''
    
pd.io.sql.read_sql(query_2, con = engine)
# Out:
#     book_id                                              title  count_review  \
# 0       948                            Twilight (Twilight  #1)             7
# 1       627                                      The Alchemist             6
# 2       497                          Outlander (Outlander  #1)             6
# 3       750                The Hobbit  or There and Back Again             6
# 4       207                                    Eat  Pray  Love             6
# 5       656                                     The Book Thief             6
# 6       695  The Curious Incident of the Dog in the Night-Time             6
# 7       673                             The Catcher in the Rye             6
# 8       733                          The Giver (The Giver  #1)             6
# 9       734                                   The Glass Castle             6
# 10      779  The Lightning Thief (Percy Jackson and the Oly...             6
# ...

# %%
query_2 = ''' 

WITH

a as 

(SELECT 
   book_id,
   COUNT(DISTINCT(review_id)) as count_review
FROM reviews
GROUP BY book_id),

b as 
(SELECT 
   book_id,
   AVG(rating) as rating_mean
FROM ratings
GROUP BY book_id),

c as
(SELECT 
   book_id,
   title
FROM books)

SELECT
    c.book_id,
    c.title,
    a.count_review,
    ROUND(b.rating_mean,2)

FROM a 
JOIN b ON a.book_id = b.book_id
JOIN c ON  b.book_id = c.book_id
ORDER BY b.rating_mean DESC
LIMIT 10;

            '''
    
pd.io.sql.read_sql(query_2, con = engine)
# Out:
#    book_id                                              title  count_review  \
# 0       86      Arrows of the Queen (Heralds of Valdemar  #1)             2
# 1      169  Crucial Conversations: Tools for Talking When ...             2
# 2       62                                      Alas  Babylon             2
# 3       57                    Act of Treason (Mitch Rapp  #9)             2
# 4       76                                        Angels Fall             2
# 5      136  Captivating: Unveiling the Mystery of a Woman'...             2
# 6       55          A Woman of Substance (Emma Harte Saga #1)             2
# 7       20              A Fistful of Charms (The Hollows  #4)             2
# 8       17                      A Dirty Job (Grim Reaper  #1)             4
# 9      182                                         Dead Souls             2
#
#    round
# 0    5.0
# 1    5.0
# 2    5.0
# 3    5.0
# 4    5.0
# 5    5.0
# 6    5.0
# 7    5.0
# 8    5.0
# 9    5.0

# %% [markdown]
#     Топ 10 книг по количество обзоров получили средние оценки между 3.60-4.30.
#     Не всегда самые популярные книги по количеству обзора получают высокую средняю оценку. Это случае с  книгой "Twilight (Twilight 1)", которая нобрала 7 обзоров и получила достаточно низкую оценку 3.66. А книга "Arrows of the Queen (Heralds of Valdemar 1)" набрала максимум оценки 5 но было только 2 обзора на ее.
#     я думаю фактор каличество обзоров очень важный и считаю книги как "Harry Potter and the Chamber of Secrets" и "The Glass Castle	" очень популярными.

# %% [markdown]
# ## Определите издательство, которое выпустило наибольшее число книг толще 50 страниц — так вы исключите из анализа брошюры;

# %%
query_3 = ''' 

SELECT
    publisher,
    COUNT(book_id)
FROM
(SELECT *
FROM publishers as p
LEFT JOIN books as b on b.publisher_id = p.publisher_id
WHERE b.num_pages>50) as table_1
GROUP BY publisher
ORDER BY count DESC
LIMIT 1;
            '''
    
pd.io.sql.read_sql(query_3, con = engine)
# Out:
#        publisher  count
# 0  Penguin Books     42

# %% [markdown]
#     издательство, которое выпустило наибольшее число книг толще 50 страниц — Називается "Penguin Books" и выпустила 42 книг

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Издательство опредили верно! Спасибо, что дополнительно выведено количество книг издательства:)
#
# </div>

# %% [markdown]
# ## Определите автора с самой высокой средней оценкой книг — учитывайте только книги с 50 и более оценками;

# %%
query_4 = ''' 

SELECT 
    *
FROM

(SELECT 
    DISTINCT(a.author),
    ROUND(AVG(rat.rating),2) as avg
    
FROM authors as a
LEFT JOIN books as b on b.author_id = a.author_id
LEFT JOIN ratings as rat on rat.book_id = b.book_id
GROUP BY a.author
HAVING COUNT(rat.rating) >= 50) as table_1
ORDER BY avg DESC
;
            '''
pd.io.sql.read_sql(query_4, con = engine)
# Out:
#                                                author   avg
# 0                                      Diana Gabaldon  4.30
# 1                          J.K. Rowling/Mary GrandPré  4.29
# 2                                     Agatha Christie  4.28
# 3                   Markus Zusak/Cao Xuân Việt Khương  4.26
# 4                                      J.R.R. Tolkien  4.24
# 5                            Roald Dahl/Quentin Blake  4.21
# 6                                   Louisa May Alcott  4.20
# 7                                        Rick Riordan  4.13
# 8                                       Arthur Golden  4.11
# 9                                        Stephen King  4.01
# 10                                       John Grisham  3.97
# 11                                    William Golding  3.90
# 12                                    Sophie Kinsella  3.88
# 13                                       Jodi Picoult  3.88
# 14                                    Nicholas Sparks  3.88
# ...

# %% [markdown]
#     J.K. Rowling/Mary GrandPré - является автором с самой высокой средней оценкой книг с 50 и более оценками. средний рейтинг автора 4.29
#
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b>
# Автора определили верно, но важно также посчитать его рейтинг: очень часто в этом задании студенты считают его неправильно, иногда даже определяют верного автора по неверному рейтингу:) Давай дополнительно посчитаем средний рейтинг автора?
#
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <h2> Комментарий студента <a class="tocSkip"> </h2>
#
# сапсибо! добавил средний рейтинг автора.

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера v.2 <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b>
# Тут две ошибки:
# 1. Условие фильтрации написано неверно: нас интересуют книги с оценками от 50 и более, а ты берёшь книги, у которых строго более 50 оценок - нужно изменить оператор сравнения.
# 2. После исправления этой ошибки твой ответ поменяется - дело в том, что ты считаешь рейтинг сразу по всем книгам, а уже только потом что-то фильтруешь. Тут есть две стратегии решения задачи:
# - считать сначала рейтинг на уровне книг (тогда твоё текущее условие фильтрации будет работать корректно), а потом из среднего рейтинга книг взять среднее - это будет средний рейтинг автора;
# - считать рейтинг сразу по автору, но в подзапросе отфильтровать книги, которые будут участвовать в расчёте.
#
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <h2> Комментарий студента V2 <a class="tocSkip"> </h2>
#
# сапсибо! сделал изменения ниже:
#
# J.K. Rowling/Mary GrandPré - является автором с самой высокой средней оценкой книг с 50 и более оценками. средний рейтинг автора 4.29

# %%
query_4 = ''' 

SELECT
    author,
    AVG(avg_rating)

FROM 

(SELECT
        a.author,
        b.author_id,
        b.book_id,
        AVG(rat.rating) AS avg_rating

FROM authors as a
LEFT JOIN books as b on b.author_id = a.author_id
LEFT JOIN ratings as rat on rat.book_id = b.book_id
GROUP BY b.book_id,b.author_id,a.author
HAVING COUNT(rat.rating) >= 50
ORDER BY avg_rating DESC) as table_1

GROUP BY author
ORDER BY avg DESC

;
            '''
pd.io.sql.read_sql(query_4, con = engine)
# Out:
#                                                author       avg
# 0                          J.K. Rowling/Mary GrandPré  4.283844
# 1                   Markus Zusak/Cao Xuân Việt Khương  4.264151
# 2                                      J.R.R. Tolkien  4.258446
# 3                                   Louisa May Alcott  4.192308
# 4                                        Rick Riordan  4.080645
# 5                                     William Golding  3.901408
# 6                                       J.D. Salinger  3.825581
# 7            Paulo Coelho/Alan R. Clarke/Özdemir İnce  3.789474
# 8   William Shakespeare/Paul Werstine/Barbara A. M...  3.787879
# 9                                           Dan Brown  3.754540
# 10                                         Lois Lowry  3.750000
# 11            George Orwell/Boris Grabnar/Peter Škerl  3.729730
# 12                                    Stephenie Meyer  3.662500
# 13                                     John Steinbeck  3.622951

# %%
query_4 = ''' 


SELECT
    a.author,
    AVG(table_1.rating)

FROM
(SELECT 
    b.book_id,
    b.author_id,
    AVG(rating) as rating
FROM
books AS b
LEFT JOIN ratings as rat on rat.book_id = b.book_id
GROUP BY b.book_id
HAVING COUNT(rat.rating) >= 50
ORDER BY rating DESC) as table_1

LEFT JOIN authors AS a on table_1.author_id = a.author_id

GROUP BY a.author
ORDER BY avg DESC


 '''

pd.io.sql.read_sql(query_4, con = engine)
# Out:
#                                                author       avg
# 0                          J.K. Rowling/Mary GrandPré  4.283844
# 1                   Markus Zusak/Cao Xuân Việt Khương  4.264151
# 2                                      J.R.R. Tolkien  4.258446
# 3                                   Louisa May Alcott  4.192308
# 4                                        Rick Riordan  4.080645
# 5                                     William Golding  3.901408
# 6                                       J.D. Salinger  3.825581
# 7            Paulo Coelho/Alan R. Clarke/Özdemir İnce  3.789474
# 8   William Shakespeare/Paul Werstine/Barbara A. M...  3.787879
# 9                                           Dan Brown  3.754540
# 10                                         Lois Lowry  3.750000
# 11            George Orwell/Boris Grabnar/Peter Škerl  3.729730
# 12                                    Stephenie Meyer  3.662500
# 13                                     John Steinbeck  3.622951

# %% [markdown]
# ## Посчитайте среднее количество обзоров от пользователей, которые поставили больше 50 оценок.

# %%
query_5 = ''' 


SELECT 
    FLOOR(AVG(count))
FROM

(SELECT 
    username,
  COUNT(review_id)
FROM reviews

WHERE username IN

(SELECT username

FROM ratings
GROUP BY username
Having COUNT(rating_id) > 50) 
GROUP BY username) as reviews_user
;
            '''
       
    
pd.io.sql.read_sql(query_5, con = engine)
# Out:
#    floor
# 0   24.0

# %% [markdown]
#     24 - это среднее количество обзоров от пользователей, которые поставили больше 50 оценок.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Среднее количество обзоров от пользователей, которые поставили больше 50 оценок, посчитано верно! Здорово, что эта метрика округлена до целого - важно не только уметь писать запросы, но и понимать данные, с которыми работаешь:)
#
# </div>

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации⚠️:</b>
# По завершении проекта стоит сделать итоговый вывод: в него можно включить основные шаги проекта, а также ключевые выводы, полученные в ходе работы над ним.
#         </div>

# %% [markdown]
# <div class="alert alert-info">
# <h2> Комментарий студента <a class="tocSkip"> </h2>
#
# спасибо. делаю ниже:

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v.2 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Учтено!
#
# </div>

# %% [markdown]
# `Итоговый вывод и рекомендации:`
#
#     Чтобы сформулировать ценностное предложение для нового продукта yужно взять в расчет некоторые факторы:
#
#     - После 1 января 2000 года вышло 819, стоит предлогать читателем свежие книги...
#     - Нужно предлагать будущем клиентам популярные книги. важный фактор играет здесь количество обзоров и средняя оценка читателей. Пример, книги про Гари Потер очень поплярные.
#     - Самое популярное издательство по толстым книгам является Penguin Books.
#     - Есть активные  пользователей которые оставляют часто оценок, 24 - среднее количество обзоров от пользователей которые поставили больше 50 оценок.

# %% [markdown]
# <div style="border:solid Chocolate 2px; padding: 40px">
#
# # Комментарий ревьюера: общий вывод по проекту.
#
# Отличный старт работы над проектом - тебе удалось верно выполнить часть заданий и создать крепкую основу будущего крутого проекта!
#
# Мне нравится твой аналитический подход к выполнению проекта, ты соблюдаешь структуру работы, выполняешь её последовательно - это очень хорошо! Шаги проекта выполнены по порядку согласно плану проекта, нет смысловых и структурных ям. Важно, что не забываешь про выводы.
#
# SQL запросы написаны хорошо и оптимально, в них нет избыточных действий, они возвращают верный результат - это здорово, кажется, пробелов в теме по SQL не осталось:)
#
# Есть небольшие рекомендации по улучшению проекта - некритичная мелочь, которая не займёт много времени, но сделает твой проект стилистически более совершенным. Будет классно, если эти рекомендации будут учтены в твоей работе:)
#
# Также в проекте есть критические замечания - к ним я оставил комментарии красного цвета с пояснениями внутри. Важно устранить эти замечания, чтобы проект был принят.
#
# Также буду рад ответить на любые твои вопросы по проекту или на какие-либо другие, если они у тебя имеются - оставь их в комментариях, и я постараюсь ответить:)
#
# Жду твой проект на повторном ревью. До встречи:)

# %% [markdown]
# <div style="border:solid Chocolate 2px; padding: 40px">
#
# # Комментарий ревьюера: общий вывод по проекту v.2.
#
# Видимо, ты пропустил мою просьбу представиться во вступительном комментарии: я всё ещё хотел бы узнать твоё имя, чтобы обращаться к тебе персональнее:)
#
# Спасибо, что прислал проект на повторное ревью - комментарии были учтены.
#
# К одному заданию ещё стоит вернуться - в комментарии к нему ты найдёшь пояснения о том, как нужно скорректировать решение.
#
# Жду твой проект снова:)
